# %% [markdown]
# # Propt Template Generator
# ---
# This code just generates a list of new prompt templates for each relation, by paraphrasing each original template many times using the Pegasus language model. The new prompt templates are exported as a json file.
#
# ---

# %% [markdown]
# Paraphraser: https://huggingface.co/tuner007/pegasus_paraphrase
# Dataset with orig templates: https://huggingface.co/datasets/lama

# %%
# %%capture
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece

# %%
# Troubleshooting: https://stackoverflow.com/questions/65854722/huggingface-albert-tokenizer-nonetype-error-with-colab

import pandas as pd
import torch
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
model_name = 'tuner007/pegasus_paraphrase' 
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)

# paraphrase method - paraphrases one string (TODO: can it do a list of multiple strings?? i think so, given that input_text is immediately list-ified)
# return string[]? - list of paraphrases of input_text
def paraphrase_pegasus(input_text, num_return_sequences, num_beams=10, max_tokens=20): # TODO: limit max length??
  batch = tokenizer([input_text],truncation=True,padding='longest',max_length=max_tokens, return_tensors="pt").to(torch_device)
  translated = model.generate(**batch, max_length=max_tokens, num_beams=num_beams, num_return_sequences=num_return_sequences, temperature=1.5) # TODO - try different temperatures?
  tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
  return tgt_text
# Out:
# Downloading:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.12G [00:00<?, ?B/s]

# %%
from datasets import load_dataset

dataset = load_dataset("lama")
dataset
# Out:
# Downloading builder script:   0%|          | 0.00/2.86k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# No config specified, defaulting to: lama/trex
# Downloading and preparing dataset lama/trex (download: 71.19 MiB, generated: 626.48 MiB, post-processed: Unknown size, total: 697.68 MiB) to /root/.cache/huggingface/datasets/lama/trex/1.1.0/430016dd70224564ad385a96e0e4a3f88aeb5beaf4e34a8cf65b390fbc83aed7...
# Downloading data:   0%|          | 0.00/74.6M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1304391 [00:00<?, ? examples/s]
# Dataset lama downloaded and prepared to /root/.cache/huggingface/datasets/lama/trex/1.1.0/430016dd70224564ad385a96e0e4a3f88aeb5beaf4e34a8cf65b390fbc83aed7. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['uuid', 'obj_uri', 'obj_label', 'sub_uri', 'sub_label', 'predicate_id', 'sub_surface', 'obj_surface', 'masked_sentence', 'template', 'template_negated', 'label', 'description', 'type'],
#         num_rows: 1304391
#     })
# })

# %%
train_df = dataset["train"].to_pandas()
train_df.sample(5)
# Out:
#                                         uuid  obj_uri  obj_label  sub_uri  \
# 437168  43da065d-6002-44ec-bb01-3f11bfc15748     Q419       Peru     Q298
# 5139    5f830228-5233-4785-96e8-c6a876b2a994  Q168052  Lancaster  Q985279
# 488091  fdd2bef6-de6d-4bf0-b070-c7645bcc5f3a     Q865     Taiwan      Q17
# 951700  92797ef8-9120-40c5-a02b-871cec231b34      Q38      Italy      Q39
# 635283  9a32b64b-ab6e-475b-bc8c-06c48d100262     Q829       Utah    Q1522
#
#           sub_label predicate_id  sub_surface obj_surface  \
# 437168        Chile          P47        Chile        Peru
# 5139      Morecambe         P131    Morecambe   Lancaster
# 488091        Japan          P47        Japan      Taiwan
# 951700  Switzerland         P530  Switzerland       Italy
# 635283   New Mexico          P47   New Mexico        Utah
#
#                                           masked_sentence  \
# 437168  As is the case with many gulls, it has traditi...
# 5139    It is an active Anglican parish church in the ...
# 488091  It is found in China, India, Russia, [MASK] an...
# 951700  The program of the party included the idea of ...
# 635283  It was described from the Klamath Lakes area i...
#
#                                              template  \
# 437168                   [X] shares border with [Y] .
# 5139                          [X] is located in [Y] .
# 488091                   [X] shares border with [Y] .
# 951700  [X] maintains diplomatic relations with [Y] .
# 635283                   [X] shares border with [Y] .
#
#                                          template_negated  \
# 437168               [X] does not share border with [Y] .
# 5139                          [X] is not located in [Y] .
# 488091               [X] does not share border with [Y] .
# 951700  [X] does not maintain diplomatic relations wit...
# 635283               [X] does not share border with [Y] .
#
#                                                    label  \
# 437168                                shares border with
# 5139    located in the administrative territorial entity
# 488091                                shares border with
# 951700                               diplomatic relation
# 635283                                shares border with
#
#                                               description type
# 437168  countries or administrative subdivisions, of e...  N-M
# 5139    the item is located on the territory of the fo...  N-1
# 488091  countries or administrative subdivisions, of e...  N-M
# 951700                diplomatic relations of the country  N-M
# 635283  countries or administrative subdivisions, of e...  N-M

# %%
# GOAL: get a list of prompt templates for each relation
# loop over each relation id, pick a random entry for that id (they all have same template), generate new prompts from the original template.

# given a row, generate prompts
def generate_prompts(row, num_paraphrases=40):
  template = row['template']
  # orig_prompt = template.replace('[X]', row['sub_label']).replace('[Y]', row['obj_label'])   # plug subject and object into template
  
  # feed template into paraphraser as is (but remove brackets first)
  orig_prompt = template.replace("[", "").replace("]", "") 
  new_sentences = paraphrase_pegasus(orig_prompt, num_paraphrases, num_beams=num_paraphrases) # list?
  new_sentences = [sentence.replace(' X ', ' [X] ').replace(' Y ', ' [Y] ').replace(' X.', ' [X].').replace(' Y.', ' [Y].').replace('X ', '[X] ').replace('Y ', '[Y] ').replace(' X', ' [X]').replace(' Y', ' [Y]') for sentence in new_sentences]
  # TODO: check no multiple masks !!!!!!!!!!!!!!!
  print(new_sentences)
  return new_sentences

# create dict containing lists of generated propmt templates for each relation
subset_dict = {}
relations = train_df['predicate_id'].unique() 
for r in relations:
  subset_df = train_df[train_df['predicate_id'] == r].sample(1)
  subset_df['generated_prompts'] = subset_df.apply(generate_prompts, axis=1)
  subset_dict[r] = subset_df
# Out:
# ['[Y] is where [X] is located.', '[Y] is the location of [X].', 'The location of [X] is in [Y].', '[X] is in [Y].', 'There is a place called [X] located in [Y].', 'The location of [X] is [Y].', 'There is a place called [X] in [Y].', '[Y] is located in [X].', 'You can find [X] in [Y].', '[X] is located in [Y].', 'In [Y] is where [X] is located.', '[Y] is the location for [X].', '[Y] is the place where [X] is located.', '[X] is in the same location as [Y].', 'In [Y], there is [X].', 'The place called [X] is located in [Y].', '[Y] is where [X] is.', '[X] is in the same area as [Y].', '[X] is in the same place as [Y].', 'There is [X] in [Y].', 'There is [X] located in [Y].', 'It is located in [Y].', 'In [Y] is the location of [X].', 'There is a street called [X] located in [Y].', '[Y] has [X] located in it.', 'There is a place named [X] located in [Y].', 'There is a street called [X] in [Y].', 'There is a person located in [Y].', '[X] is in the same city as [Y].', '[X] can be found in [Y].', '[X] is in the city of [Y].', 'There is a street named [X] located in [Y].', '[X] is located in the same location as [Y].', '[X] is located in the same area as [Y].', 'There is a place named [X] in [Y].', 'A person is located in [Y].', '[X] is located in the same place as [Y].', '[Y] has [X] in it.', "It's located in [Y].", 'There is a person in [Y].']
# ['[Y] is where [X] is located.', '[Y] is the location of [X].', 'The location of [X] is in [Y].', '[X] is in [Y].', 'There is a place called [X] located in [Y].', 'The location of [X] is [Y].', 'There is a place called [X] in [Y].', '[Y] is located in [X].', 'You can find [X] in [Y].', '[X] is located in [Y].', 'In [Y] is where [X] is located.', '[Y] is the location for [X].', '[Y] is the place where [X] is located.', '[X] is in the same location as [Y].', 'In [Y], there is [X].', 'The place called [X] is located in [Y].', '[Y] is where [X] is.', '[X] is in the same area as [Y].', '[X] is in the same place as [Y].', 'There is [X] in [Y].', 'There is [X] located in [Y].', 'It is located in [Y].', 'In [Y] is the location of [X].', 'There is a street called [X] located in [Y].', '[Y] has [X] located in it.', 'There is a place named [X] located in [Y].', 'There is a street called [X] in [Y].', 'There is a person located in [Y].', '[X] is in the same city as [Y].', '[X] can be found in [Y].', '[X] is in the city of [Y].', 'There is a street named [X] located in [Y].', '[X] is located in the same location as [Y].', '[X] is located in the same area as [Y].', 'There is a place named [X] in [Y].', 'A person is located in [Y].', '[X] is located in the same place as [Y].', '[Y] has [X] in it.', "It's located in [Y].", 'There is a person in [Y].']
# ['[X] plays music.', '[Y] music is played by [X].', '[X] is playing music.', '[Y] music is being played by [X].', '[Y] music plays in the background.', '[X] plays a song.', '[X] is playing [Y] music.', 'A person plays music.', '[X] plays music', '[Y] music plays as [X] plays it.', '[X] plays [Y] music.', "[Y] music plays in [X]'s headphones.", '[Y] music is plays by [X].', 'The person plays music.', 'The person plays [Y] music.', '[Y] is the music that [X] plays.', "[Y] plays [X]'s music.", '[Y] music played by [X].', 'The [X] plays music.', "[Y] music plays in [X]'s ears.", '[X] plays music for others.', 'The person is playing [Y] music.', '[Y] music is played by [X]', "[Y] music plays in [X]'s music player.", '[Y] plays [X] music.', '[Y] is the music [X] plays.', "[Y] music plays in [X]'s ear.", '[X] is a musician.', '[Y] music plays in the background as [X] plays it.', '[Y] is played by [X].', '[X] plays an instrument.', '[X] plays some music.', '[X] plays the music.', '[X] plays music for other people.', '[Y] is played by [X] when he plays music.', 'There is a person playing [Y] music.', '[Y] is played by [X] as he plays music.', "[Y] music plays in [X]'s head.", 'A man plays music.', "[Y] music plays on [X]'s headphones."]
# ['[Y] is where [X] is located.', '[Y] is the location of [X].', 'The location of [X] is in [Y].', '[X] is in [Y].', 'There is a place called [X] located in [Y].', 'The location of [X] is [Y].', 'There is a place called [X] in [Y].', '[Y] is located in [X].', 'You can find [X] in [Y].', '[X] is located in [Y].', 'In [Y] is where [X] is located.', '[Y] is the location for [X].', '[Y] is the place where [X] is located.', '[X] is in the same location as [Y].', 'In [Y], there is [X].', 'The place called [X] is located in [Y].', '[Y] is where [X] is.', '[X] is in the same area as [Y].', '[X] is in the same place as [Y].', 'There is [X] in [Y].', 'There is [X] located in [Y].', 'It is located in [Y].', 'In [Y] is the location of [X].', 'There is a street called [X] located in [Y].', '[Y] has [X] located in it.', 'There is a place named [X] located in [Y].', 'There is a street called [X] in [Y].', 'There is a person located in [Y].', '[X] is in the same city as [Y].', '[X] can be found in [Y].', '[X] is in the city of [Y].', 'There is a street named [X] located in [Y].', '[X] is located in the same location as [Y].', '[X] is located in the same area as [Y].', 'There is a place named [X] in [Y].', 'A person is located in [Y].', '[X] is located in the same place as [Y].', '[Y] has [X] in it.', "It's located in [Y].", 'There is a person in [Y].']
# ['[Y] was where [X] was founded.', '[Y] is where [X] was founded.', '[X] was founded in [Y].', 'In [Y], [X] was founded.', '[X] was started in [Y].', '[Y] was the location of [X].', 'It was founded in [Y].', '[X] was established in [Y].', 'In [Y] is where [X] was founded.', '[X] was born in [Y].', 'The company was founded in [Y].', '[Y] was where [X] was born.', '[Y] was the location where [X] was founded.', '[X] was created in [Y].', '[Y] is the location of [X].', '[Y] was the place where [X] was founded.', '[X] was founded in the year [Y].', 'In [Y], there was a company called [X].', 'The founding of [X] was in [Y].', '[X] was formed in [Y].', 'In [Y] was founded [X].', '[X] was founded in the same place as [Y].', '[X] was founded by [Y].', '[Y] was the birthplace of [X].', 'A company called [X] was founded in [Y].', '[Y] was where [X] was started.', 'The company [X] was founded in [Y].', '[Y] is where [X] was started.', '[X] was launched in [Y].', '[Y] is where [X] was born.', '[Y] was where [X] started.', '[Y] was where [X] came from.', '[X] was founded in a different place.', '[Y] was where [X] began.', 'The company [X] was founded in.', 'The location of [X] was [Y].', '[X] was founded in the same place.', '[X] was begun in [Y].', '[X] was founded in another place.', 'In [Y], there was a place called [X].']
# ['[X] is a member of the [Y] religion.', '[X] is affiliated with the [Y] religion.', 'The [Y] religion is affiliated with [X].', '[X] is associated with the [Y] religion.', '[X] is affiliated with a religion.', '[X] is related to the [Y] religion.', 'The [Y] religion is associated with [X].', 'The [Y] religion has [X] as a member.', 'The [Y] religion has [X] as an affiliated member.', '[X] is part of the [Y] religion.', '[X] is a part of the [Y] religion.', 'The [Y] religion has an affiliation with [X].', '[X] is connected to the [Y] religion.', 'The [Y] religion has [X] affiliated with it.', 'A person named [X] is affiliated with the [Y] religion.', 'The [Y] religion has an affiliated person named [X].', 'There is a person affiliated with the [Y] religion.', '[X] has an affiliation with the [Y] religion.', '[X] is linked to the [Y] religion.', 'The [Y] religion has an affiliated person called [X].', 'The [Y] religion has a member named [X].', 'The [Y] religion has a person named [X].', '[X] is an affiliated member of the [Y] religion.', 'The [Y] religion has a person named [X] who is affiliated with it.', 'The [Y] religion has a person affiliated with it.', 'A person named [X] is affiliated with a religion.', 'The [Y] religion has a person named [X] affiliated with it.', 'The [Y] religion has a member called [X].', '[X] is affiliated with another religion.', 'The [Y] religion has [X] associated with it.', '[X] belongs to the [Y] religion.', '[Y] religion is affiliated with [X].', 'The [Y] religion has an affiliated member called [X].', '[X] is affiliated with the [Y] religion', 'The [Y] religion has a person named [X] associated with it.', 'The [Y] religion has a person associated with it.', 'The [Y] religion has an affiliated member named [X].', '[X] is members of the [Y] religion.', 'The [Y] religion has a person associated with them.', '[X] is connected with the [Y] religion.']
# ['[Y] is the official language of [X].', 'The official language of [X] is [Y].', 'The language of [X] is [Y].', 'The official language is [Y].', "X's official language is [Y].", 'The official language for [X] is [Y].', 'The official language in [X] is [Y].', '[Y] is the official language.', '[Y] is the official language for [X].', '[Y] is the official language in [X].', '[Y] is the language of [X].', '[X] has an official language called [Y].', 'The [Y] is the official language of [X].', '[Y] is the official Language of [X].', 'It is the official language of [X].', '[Y] is the Official Language of [X].', 'The language of [X] is called [Y].', '[X] is written in [Y].', '[Y] is the official language of [X]', 'The official language of [X] is [Y]', '[Y] is the official language ofX.', "It's the official language of [X].", 'The official tongue of [X] is [Y].', 'The main language of [X] is [Y].', '[Y] is the officiallanguage of [X].', '[Y] is the official language of x.', '[X] has an official language of [Y].', 'The official language of [X] is called [Y].', 'The official language of[X] is [Y].', 'The official language of the [X] is [Y].', "[Y] is [X]'s official language.", 'The official Language of [X] is [Y].', 'There is a language called [Y] in [X].', 'The official language of [X] is [Y].', 'The Official Language of [X] is [Y].', 'There is an official language of [X].', 'There is an official language for [X].', '[Y] is an official language of [X].', '[X] uses the official language of [Y].', '[Y] is the official language of [X].']
# ['[X] is in the [Y] position.', '[X] plays in the [Y] position.', '[X] is in [Y] position.', '[X] plays in [Y] position.', '[X] is playing in the [Y] position.', '[X] plays in the [Y] position', '[Y] is where [X] plays.', 'In [Y] position, [X] plays.', '[X] plays in [Y].', '[X] is in a [Y] position.', 'In the [Y] position, [X] plays.', '[X] plays in a [Y] position.', '[X] plays in [Y] position', '[X] is playing in [Y] position.', '[X] is a player in the [Y] position.', '[Y] is the position [X] plays in.', 'The person plays in the [Y] position.', 'The person is in the [Y] position.', 'The [X] plays in the [Y] position.', 'The player is in the [Y] position.', 'The person is in [Y] position.', '[X] is in the [Y] position', 'The person plays in [Y] position.', '[Y] is the position where [X] plays.', 'The player is in [Y] position.', '[X] plays in a certain position.', 'There is a person in the [Y] position.', '[X] plays in the middle of the field.', 'There is a player in the [Y] position.', '[X] is in [Y] position', 'The person is playing in [Y] position.', '[X] plays the [Y] position.', '[X] is in [Y].', 'In [Y] position is [X].', '[X] is in the position of [Y].', 'The [X] plays in [Y] position.', 'The player plays in [Y] position.', 'In [Y] position, [X] is playing.', '[Y] is the position [X] plays.', 'In the [Y] position is [X].']
# ['The headquarters of [X] is in [Y].', 'The headquarters of [X] is located in [Y].', 'The headquarters of [X] are in [Y].', '[Y] is the headquarters of [X].', "X's headquarters is in [Y].", '[Y] is where the headquarter of [X] is located.', 'In [Y] is the headquarters of [X].', 'The head office of [X] is in [Y].', '[Y] is where the headquarters of [X] is located.', '[Y] is where the headquarters of [X] are located.', 'The office of [X] is in [Y].', "It's the headquarters of [X] in [Y].", '[Y] is the headquarter of [X].', 'In [Y], the headquarters of [X] is located.', 'The main office of [X] is in [Y].', 'There is a headquarters for [X] in [Y].', 'There is a headquarter of [X] in [Y].', 'The location of the headquarters of [X] is in [Y].', 'The base of [X] is in [Y].', 'The headquarter of [X] is in [Y].', 'The office of [X] is located in [Y].', 'The [X] headquarters is in [Y].', "X's head office is in [Y].", 'The [Y] is where the headquarters of [X] are located.', 'There is a headquarter for [X] in [Y].', 'There is a headquarters of [X] in [Y].', 'In [Y] is the headquarter of [X].', 'The headquarters of [X] are located in [Y].', '[Y] is the location of the headquarter of [X].', 'It is the headquarters of [X] in [Y].', '[Y] is the location of the headquarters of [X].', 'The head office of [X] is located in [Y].', 'The headquarter of [X] is located in [Y].', 'The headquarters is in [Y].', 'The location of the headquarters of [X] is [Y].', 'There is a headquarter in [Y].', '[Y] is where the headquarter of [X] is.', 'The headquarters of the organization is in [Y].', 'In [Y] the headquarters of [X] is located.', 'In [Y], the headquarters of [X] is.']
# ['[Y] was where [X] was born.', '[X] was born in [Y].', '[Y] is where [X] was born.', 'The baby was born in [Y].', 'The child was born in [Y].', "[Y] was the location of [X]'s birth.", "[Y] is the location of [X]'s birth.", '[X] was born in the year [Y].', '[Y] was the location where [X] was born.', '[X] was born in the same place as [Y].', '[Y] was the place where [X] was born.', '[Y] is the place where [X] was born.', 'The person was born in [Y].', 'There was a baby born in [Y].', 'It was [X] who was born in [Y].', 'In [Y], [X] was born.', 'He was born in [Y].', 'In [Y] is where [X] was born.', 'In [Y] was where [X] was born.', '[Y] was the birth place of [X].', 'The birth place of [X] was [Y].', 'A person was born in [Y].', 'The born in [Y] was [X].', 'There is a baby born in [Y].', '[X] was born on [Y].', 'The baby was born in the same place as [Y].', '[X] was born in a different place.', '[Y] was the place [X] was born in.', '[X] was born in the same location as [Y].', '[Y] was the place [X] was born.', '[X] was born in [Y]', 'There was a baby in [Y].', 'I was born in [Y].', '[X] was born into a family.', '[X] was born in a different location.', 'There was a person born in [Y].', '[X] was born in a different place than [Y].', '[X] was born in the same year.', '[X] was born in the same city as [Y].', '[X] was born in [Y].']
# ['[X] is a subclass of [Y].', '[Y] is a subclass of [X].', 'A subclass of [Y] is [X].', 'The subclass of [Y] is called [X].', 'The subclass of [Y] is [X].', 'There are two subclasses of [Y], [X] and [Y].', 'There is a subclass of [Y] called [X].', 'There are two subclasses of [Y]: [X] and [Y].', "It's a subclass of [Y].", '[X] is a subclass of [Y]', 'There is a subclass of [Y].', 'A subclass of [Y] is called [X].', 'It is a subclass of [Y].', 'There are two subclasses of [Y].', "There's a subclass of [Y] called [X].", 'There are two subclass of [Y], [X] and [Y].', '[X] is one of the subclasses of [Y].', 'The subclass of [Y] is known as [X].', 'There are two subclasses of [Y] - [X] and [Y].', 'There are two subclasses of [Y] called [X] and [Y].', 'A subclass of [Y] called [X] is also called a subclass of [Y].', 'The subclass [Y] is called [X].', 'The subclass of [Y] is referred to as [X].', 'The subclass of [X] is [Y].', 'The subclass [X] is called [Y].', '[X] is part of [Y].', 'There is a subclass of [Y] that is called [X].', '[X] and [Y] are subclasses of one another.', '[X] is the subclass of [Y].', "It's a subclass of [Y] called [X].", 'There are two subclasses of [Y]; [X] and [Y].', "There's a subclass of [Y] that's called [X].", '[X] is a subclass.', 'There are three subclasses of [Y]: [X], [Y] and [X].', '[X] and [Y] are subclasses of [Y].', 'The subclass of [X] is called [Y].', 'There are two subclasses of [Y], called [X] and [Y].', 'There are two subclass of [Y].', 'This is a subclass of [Y].', "It's a subclass of [Y] that's called [X]."]
# ['[X] is a citizen.', '[Y] is a citizen.', '[Y] is a citizen of [X].', '[Y] citizen is [X].', '[Y] is a citizen of the United States.', '[X] is a citizen of [Y].', '[X] is a citizen of the United States.', '[Y] is the citizen of [X].', '[Y] is a citizen of the United States of America.', 'The person is called [Y] citizen.', 'There is a person named [X] who is a citizen.', 'There is a person called [X] who is a citizen.', '[Y] is a citizen of the US.', 'The person is a citizen.', '[Y] is a citizen of the world.', '[X] is a citizen of the United States of America.', "[Y] is [X]'s citizenship.", '[Y] is a citizen and [X] is not.', '[X] is a citizen of the world.', '[X] is a citizen of the US.', '[X] is a citizen of the country.', 'A person named [X] is a citizen of another country named [Y].', '[X] is a person who is a citizen.', '[Y] is a citizen of the country.', '[Y] is an American citizen.', 'Is [X] a citizen?', '[X] is a citizen of the nation.', '[X] is a citizen of the state.', '[Y] is a citizen of the nation.', 'There is a person named [X] who is a [Y] citizen.', 'The person is [Y] citizen.', 'There is a person called [X] who is a [Y] citizen.', 'There is a person named [X] who is a citizen of another country.', 'There is a person called [X] who is [Y] citizen.', '[Y] citizens are [X] and [Y].', 'There is a person called [X] who is a citizen of [Y].', 'A person named [X] is a citizen of another country.', 'A person named [X] is a citizen of [Y].', 'There is a person called [X] who is a citizen of another country.', 'There is a person who is [Y] citizen.']
# ['[X] died in [Y].', '[X] passed away in [Y].', '[Y] was where [X] died.', 'There was a death in [Y].', 'In [Y], [X] died.', 'The person died in [Y].', '[Y] is where [X] died.', 'It was [X] who died in [Y].', 'There was a person who died in [Y].', 'He died in [Y].', 'The body of [X] was found in [Y].', 'The person died in the other place.', "[Y] died of [X]'s death.", 'In [Y], [X] passed away.', '[X] was dead in [Y].', '[Y] was the place where [X] died.', 'It was [X] that died in [Y].', 'The death of [X] occurred in [Y].', 'The death of [X] was recorded in [Y].', 'The death of [X] happened in [Y].', '[Y] was the place [X] died in.', '[Y] was the location where [X] died.', 'The man died in [Y].', '[Y] was where [X] passed away.', '[X] expired in [Y].', 'There was a death in [Y] of [X].', '[Y] was the place [X] died.', '[X] died in [Y]', '[X] passed away in [Y].', 'The person died in the other room.', '[Y] had [X] die in it.', '[X] was killed in [Y].', 'The person died in the other person.', '[X] is dead in [Y].', 'A person died in another person.', '[X] died while in [Y].', 'A person died in [Y].', 'The person died in the other direction.', 'The person died in the other body of water.', 'The person died in the same place as [X].']
# ['[Y] is the native language of [X].', 'The native language of [X] is [Y].', 'The language of [X] is [Y].', 'The [Y] is the native language of [X].', 'The native language is [Y].', "X's native language is [Y].", 'The native tongue of [X] is [Y].', 'The native language for [X] is [Y].', '[Y] is the native language for [X].', 'The [Y] language is the native language of [X].', '[Y] is the language of [X].', '[Y] is a native language of [X].', 'There is a native language of [X].', 'The language [Y] is the native language of [X].', '[Y] is the native Language of [X].', 'The native language of the people of [X] is [Y].', '[Y] is the official language of [X].', 'The native language in [X] is [Y].', '[Y] is the native language of [X]', '[Y] is the native language ofX.', 'A native language of [X] is [Y].', '[Y] is the native tongue of [X].', '[X] is a native language of [Y].', '[Y] is the native language in [X].', 'There is a native language for [X].', '[Y] is the main language of [X].', 'The native language of the people is [Y].', 'The main language of [X] is [Y].', '[Y] is the primary language of [X].', '[Y] is the native language.', 'The native language of [X] is [Y]', 'The official language of [X] is [Y].', '[Y] is the native language of the people of [X].', 'It is the native language of [X].', 'The native Language of [X] is [Y].', '[Y] is the native language of x.', '[Y] is the native language of the [X] race.', 'The [Y] language is the native one of [X].', 'The native language of [Y] is [X].', '[X] is a language with a native language of [Y].']
# ['[Y] is part of [X].', '[Y] is a part of [X].', '[Y] and [X] are part of the same thing.', '[X] is part of [Y].', '[X] is a part of [Y].', 'A part of [Y] is [X].', 'Part of [Y] is [X].', "It's part of [Y].", '[Y] and [X] are part of the same entity.', '[X] and [Y] are part of the same thing.', '[Y] and [X] are both part of the same thing.', 'The part of [Y] that is known as [X] is part of [Y].', '[Y] and [X] are part of each other.', '[Y] and [X] are part of the same place.', 'The part of [Y] that is known as [X] is also known as [Y].', 'It is part of [Y].', 'You can see that [X] is part of [Y].', 'There are two parts to [Y], [X] and [Y].', '[Y] and [X] are both part of it.', '[Y] and [X] are part of the same universe.', "It's a part of [Y].", '[Y] and [X] are part of the same body.', '[X] and [Y] are both part of the same thing.', '[Y] and [X] are part of the same family.', '[Y] and [X] are part of the same structure.', '[Y] and [X] are related.', 'The part of [Y] that is called [X] is called [Y].', 'The part of [Y] that is called [X] is part of [Y].', '[Y] and [X] are part of the same group.', '[Y] and [X] are parts of the same thing.', '[X] and [Y] are part of the same entity.', '[Y] and [X] are part of the same body of water.', 'The part of [Y] that is known as [X] is part of [Y] as well.', '[Y] and [X] are part of the same system.', '[Y] and [X] are both part of the same entity.', '[Y] and [X] are part of it.', '[Y] and [X] are both part of the same place.', 'The part of [Y] that is called [X] is also called [Y].', 'The part of [Y] called [X] is part of [X].', '[Y] and [X] are part of one.']
# ['[Y] is where [X] is located.', '[Y] is the location of [X].', 'The location of [X] is in [Y].', '[X] is in [Y].', 'There is a place called [X] located in [Y].', 'The location of [X] is [Y].', 'There is a place called [X] in [Y].', '[Y] is located in [X].', 'You can find [X] in [Y].', '[X] is located in [Y].', 'In [Y] is where [X] is located.', '[Y] is the location for [X].', '[Y] is the place where [X] is located.', '[X] is in the same location as [Y].', 'In [Y], there is [X].', 'The place called [X] is located in [Y].', '[Y] is where [X] is.', '[X] is in the same area as [Y].', '[X] is in the same place as [Y].', 'There is [X] in [Y].', 'There is [X] located in [Y].', 'It is located in [Y].', 'In [Y] is the location of [X].', 'There is a street called [X] located in [Y].', '[Y] has [X] located in it.', 'There is a place named [X] located in [Y].', 'There is a street called [X] in [Y].', 'There is a person located in [Y].', '[X] is in the same city as [Y].', '[X] can be found in [Y].', '[X] is in the city of [Y].', 'There is a street named [X] located in [Y].', '[X] is located in the same location as [Y].', '[X] is located in the same area as [Y].', 'There is a place named [X] in [Y].', 'A person is located in [Y].', '[X] is located in the same place as [Y].', '[Y] has [X] in it.', "It's located in [Y].", 'There is a person in [Y].']
# ['[X] shares a border with [Y].', '[X] and [Y] share a border.', 'The border between [X] and [Y] is shared by 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884', 'The border is shared by [X] and [Y].', '[X] and [Y] have the same border.', '[X] has a border with [Y].', 'The border with [Y] is shared by [X] and [Y].', '[X] and [Y] share the same border.', 'The border of [X] and [Y] is shared by 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884', '[Y] shares a border with [X].', 'There is a border between [X] and [Y].', 'The [X] and [Y] border is shared by 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884', '[Y] and [X] share a border.', '[X] and [Y] are in the same area.', '[X] shares the same border with [Y].', 'Border with [Y] is shared by [X] and [Y].', '[X] and [Y] have a border.', 'The border with [Y] is shared by [X] and [X].', '[X] shares the border with [Y].', '[X] and [Y] both share a border.', 'The border is [X] and [Y].', '[X] and [Y] are near each other.', 'border with [Y] is shared by [X] and [Y].', 'The [X] and [Y] border.', 'The border between [X] and [Y] is [X].', 'The border between [X] and [Y] is shared by [X] and [Y].', '[X] and [Y] are in the same place.', 'There is a border with [Y].', '[X] and [Y] are close to each other.', '[X] and [Y] both have a border.', '[Y] and [X] share the same border.', 'Both [X] and [Y] share a border.', '[X] and [Y] are both in the same area.', '[X] shares border with [Y].', '[X] and [Y] border each other.', '[X] and [Y] are in the same border.', '[X] and [Y] share the border.', '[Y] shares border with [X].', 'The [X] and [Y] borders are similar.', 'Both [X] and [Y] have a border.']
# ['Twin cities are [X] and [Y].', 'Both [X] and [Y] are twin cities.', 'The twin cities are [X] and [Y].', 'There are two cities, [X] and [Y].', 'Both of the twin cities are [X] and [Y].', '[X] and [Y] are both twin cities.', 'There are two twin cities, [X] and [Y].', '[X] and [Y] are twin cities.', 'The cities of [X] and [Y] are twin.', 'Two cities are called [X] and [Y].', 'The cities are called [X] and [Y].', 'Twin Cities are [X] and [Y].', 'The two cities are called [X] and [Y].', 'Both [X] and [Y] are cities.', 'Both of the twin cities are called [X] and [Y].', 'Both [Y] and [X] are twin cities.', 'Two cities are [X] and [Y].', 'The cities of [X] and [Y] are identical.', 'There is a twin city called [X] and [Y].', 'The cities of [X] and [Y] are not the same.', 'The cities of [X] and [Y] are both twin cities.', '[X] and [Y] are both cities.', 'Both cities are called [X] and [Y].', '[X] and [Y] are the same city.', 'The cities of [X] and [Y] are related.', '[X] and [Y] are not the same city.', 'They are both twin cities.', 'The cities of [X] and [Y] have the same name.', 'twin cities are [X] and [Y].', '[Y] and [X] are twin cities.', 'They are twin cities.', 'The cities of [X] and [Y] are the same.', 'The cities of [X] and [Y] are similar.', 'The cities of [X] and [Y] are twin cities.', 'There are two twin cities.', 'Both [X] and [Y] are in the same area.', 'The cities of [X] and [Y] are very similar.', '[X] and [Y] are not the same.', 'Both [X] and [Y] have twin cities.', 'The cities are twin.']
# ['[X] plays [Y].', '[Y] plays [X].', '[X] is playing [Y].', '[Y] is played by [X].', '[X] plays [Y]', '[X] is in a game with [Y].', '[X] plays a game.', '[Y] is being played by [X].', 'There is a game between [X] and [Y].', '[X] and [Y] are playing.', 'There is a game called [X] plays [Y].', '[X] and [Y] play each other.', 'A person plays a game.', 'The [X] plays the [Y].', 'The player [X] plays the game [Y].', 'The player [X] plays [Y].', '[Y] is playing [X].', 'The person playing [Y] is [X].', '[X] is in a game of [Y].', '[X] and [Y] are playing a game.', 'The person is playing [Y] and [X] is playing [X].', 'The person plays [Y].', 'There is a game of [X] plays [Y].', '[X] plays [Y] in a game.', 'There is a game of [Y] and [X].', 'The player [X] plays the other player [Y].', '[X] is in a game against [Y].', 'The player [X] plays a game.', 'A person plays a board game.', 'A man plays a game.', '[X] is against [Y].', 'A player plays a game.', "It's [X] versus [Y].", 'The [X] plays [Y].', 'The person playing [Y] plays [X].', 'The person plays a game.', '[X] plays [Y].', 'The person is playing [Y] and [X] plays [X].', 'The person is playing [Y] and [X].', '[X] is playing a game.']
# ['[Y] is part of [X].', '[X] is composed of [Y].', '[X] is comprised of [Y].', 'There is [X] and [Y].', '[X] is made up of [Y].', 'The [X] consists of [Y].', '[Y] is a part of [X].', '[Y] is included in [X].', '[Y] consists of [X].', '[Y] is comprised of [X].', '[X] consists of [Y].', 'The [X] is composed of [Y].', '[Y] is composed of [X].', 'There is [X] and [Y] in it.', '[X] and [Y] are composed of one another.', '[Y] is the part of [X].', '[X] and [Y] are part of the same thing.', 'The [X] and [Y] are part of the same thing.', 'A part of [Y] is [X].', 'The [X] is made up of [Y].', 'It consists of [Y].', '[X] has [Y] in it.', '[X] and [Y] are part of it.', 'The [X] and [Y] are composed of one another.', 'There is [X] and [Y] in this picture.', '[X] and [Y] are the same thing.', 'The [X] is comprised of [Y].', 'The [X] and [Y] are related.', '[X] and [Y] are the same.', 'The [X] and [Y] are composed of the same thing.', 'It consists of [Y] and [X].', 'The [X] consists of the [Y].', "There's [X] and [Y].", 'The [X] and [Y] are made of the same substance.', '[X] is made of [Y].', 'The [X] and [Y] are made up of the same thing.', '[Y] is in [X].', "[Y] is [X]'s part.", '[X] and [Y] are composed of the same thing.', "[Y] is [X]'s component."]
# ['[Y] was where [X] was created.', '[Y] was the place where [X] was created.', '[Y] is where [X] was created.', 'In [Y], [X] was created.', '[X] was created in [Y].', 'The creation of [X] was done in [Y].', 'It was created in [Y].', '[Y] was the location where [X] was created.', '[Y] was where [X] was born.', 'The [X] was created in [Y].', '[X] was created in the same place as [Y].', '[X] was made in [Y].', '[Y] was used to create [X].', '[Y] is the place where [X] was created.', '[Y] was where the [X] was created.', '[X] was written in [Y].', 'The creation of [X] was in [Y].', 'There was a creation in [Y].', '[Y] was the place [X] was created in.', '[Y] was where [X] came from.', '[X] was created by [Y].', '[Y] was the place where [X] was born.', '[Y] was where [X] was made.', '[Y] had [X] created in it.', '[Y] is where [X] was born.', '[X] was born in [Y].', 'There was a creation called [X] in [Y].', 'A new thing was created in [Y].', '[X] was created in a different place.', '[Y] was the place where [X] was made.', '[Y] was where the creation of [X] took place.', 'The [Y] was where [X] was created.', 'The [X] was created in the same place as [Y].', '[Y] created [X].', 'The [X] was created in the same place as the [Y].', '[X] was created in the same place.', 'The person created [X] in [Y].', 'The [X] was created in the [Y].', '[Y] was the location of [X].', 'The thing was created in [Y].']
# ['A legal term in [Y] is [X].', 'In [Y], [X] is a legal term.', 'There is a legal term called [X].', "It's a legal term in [Y].", '[X] is a legal term.', 'The legal term is [X].', 'A legal term is [X].', 'There is a legal term in [Y] called [X].', 'In [Y] there is a legal term called [X].', 'The legal term in [Y] is [X].', '[Y] has a legal term called [X].', 'In [Y], the legal term is [X].', 'The legal term [X] is in [Y].', 'In [Y], there is a legal term called [X].', 'It is a legal term in [Y].', 'There is a legal term in [Y].', 'In [Y], the term [X] is a legal one.', 'There is a legal term called [X] in [Y].', "There's a legal term in [Y] called [X].", '[Y] is the legal term for [X].', 'In [Y], the term [X] is used as a legal term.', 'There is a legal term for [X].', '[Y] is a legal term for [X].', "There's a legal term called [X] in [Y].", '[X] is a legal term in [Y].', 'In [Y], the term [X] is a legal term.', 'There is a legal term for [X] in [Y].', 'There is a legal term known as [X].', 'Legal terms in [Y] are [X] and [Y].', '[Y] is a legal term called [X].', "It's a legal term called [X] in [Y].", '[X] is a legal word.', '[Y] is a legal term.', '[X] is a legal term', 'There is a legal term for that.', 'There is a legal term in [Y] that is called [X].', 'There is a legal term for it in [Y].', 'There are legal terms in [Y].', '[Y] is a legal term that means [X].', "It's a legal term called [X]."]
# ['The capital of [Y] is [X].', '[Y] is the capital of [X].', 'The capital is [X].', 'The capital of [Y] is called [X].', '[X] is the capital of [Y].', "Y's capital is [X].", 'The capital of [Y] is x.', 'The capital of [Y] is known as [X].', 'The capital of the [Y] is [X].', "It's the capital of [Y].", 'It is the capital of [Y].', 'There is a capital [X] and a capital [Y].', '[Y] is the capital of [X]', 'The capital of [Y] is [X].', '[Y] is the capital city of [X].', '[Y] has the capital [X].', 'The capital is called [X].', '[Y] is the capital.', 'The capital city of [Y] is [X].', '[Y] has a capital [X].', '[Y] is a capital of [X].', '[Y] has a capital of [X].', "[Y] is [X]'s capital.", 'There is a capital [X].', 'the capital of [Y] is [X].', 'There is a capital of [Y].', 'The capital of [Y] is named [X].', '[Y] is the capital of [X].', '[X] is the capital of [Y]', 'The capital of [Y] is [X]', '[Y] is the capital ofX.', '[Y] has [X] as its capital.', '[Y] has [X] as the capital.', 'The capital of [Y] was [X].', 'The capital [Y] is [X].', 'The capital of [X] is [Y].', '[Y] is the capital of x.', 'A capital of [Y] is [X].', '[Y] is capital of [X].', '[Y] is the capital of the universe.']
# ['[Y] is a music label.', '[Y] is the music label that represents [X].', '[Y] is a music label that represents [X].', '[Y] is the music label for [X].', 'The music label [Y] is represented by [X].', 'Music label [Y] is represented by [X].', '[Y] is the music label represented by [X].', '[Y] is represented by [X].', '[Y] is the music label representing [X].', '[Y] is a music label for [X].', '[Y] is the music label that is represented by [X].', '[Y] is a music label that is represented by [X].', '[Y] is the music label that [X] is represented by.', 'The label [Y] is represented by [X].', 'The music label [Y] represents [X].', 'A music label called [Y] is represented by [X].', '[Y] is a music label representing [X].', '[Y] is a music label represented by [X].', '[Y] is the music label of [X].', 'A music label called [Y] represents [X].', 'Music label [Y] represents [X].', 'There is a music label called [Y].', 'The label [Y] represents [X].', '[Y] is the label that represents [X].', '[Y] is a label that represents [X].', '[X] is represented by a music label.', '[Y] is a music label with a representation of [X].', '[Y] represents [X].', "[Y] is [X]'s music label.", 'There is a music label called [X].', '[Y] is the representation of [X].', '[Y] is a music label that is associated with [X].', 'Music label [Y] is associated with [X].', '[Y] is the music label that is representing [X].', '[Y] is a music label', 'There is a music label called [Y] that represents [X].', 'A music label called [Y] is representing [X].', 'The music label [Y] has [X] represented.', '[Y] is a music label and represents [X].', '[Y] is a label for [X].']
# ['[X] and [Y] have diplomatic relations.', '[X] has diplomatic relations with [Y].', '[X] and [Y] maintain diplomatic relations.', 'There are diplomatic relations between [X] and [Y].', 'There is diplomatic relations between [X] and [Y].', '[X] maintains diplomatic relations with [Y].', '[X] and [Y] still have diplomatic relations.', '[X] and [Y] have diplomatic ties.', '[Y] and [X] have diplomatic relations.', 'Diplomatic relations with [Y] are maintained by [X].', 'diplomatic relations with [Y] are maintained by [X].', '[Y] has diplomatic relations with [X].', '[X] and [Y] have diplomatic relationships.', '[X] and [Y] still maintain diplomatic relations.', 'The [X] and [Y] have diplomatic relations.', 'The diplomatic relations between [X] and [Y] are maintained.', '[X] is in diplomatic relations with [Y].', '[X] has diplomatic ties with [Y].', 'diplomatic relations with [Y] are maintained by [X].', '[X] maintains a diplomatic relationship with [Y].', '[Y] and [X] maintain diplomatic relations.', '[X] and [Y] both have diplomatic relations.', '[X] is maintaining diplomatic relations with [Y].', '[X] maintains diplomatic relations.', 'There are diplomatic relations with [Y].', '[X] and [Y] are in diplomatic relations.', '[X] maintains relations with [Y].', 'diplomatic relations with [Y].', 'There is diplomatic relations with [Y].', '[X] has diplomatic relationships with [Y].', '[X] and [Y] hold diplomatic relations.', '[X] and [Y] have a diplomatic relationship.', '[X] holds diplomatic relations with [Y].', 'diplomatic relations with [Y] are maintained by [X]', 'The two countries have diplomatic relations with [Y].', 'diplomatic relations with [Y]', '[X] has diplomatic relations with [Y].', '[X] and [Y] share diplomatic relations.', '[X] and [Y] maintain diplomatic ties.', '[X] and [Y] do not have diplomatic relations.']
# ['The position of [X] is [Y].', 'The position of [Y] is [X].', '[X] is in the position of [Y].', '[Y] is the position of [X].', 'The position is [Y].', 'There is a position of [X] and [Y].', 'There is a position of [Y].', 'The position is [X] and [Y].', 'The position of [Y] is held by [X].', '[X] is in the same position as [Y].', '[X] is in the position [Y].', 'The position of [Y] is that of [X].', 'There is a person with the position of [Y].', '[Y] has the position of [X].', 'The position of [Y] is occupied by [X].', 'The position of [Y] is known as [X].', 'The position of [X] is called [Y].', "[Y] is [X]'s position.", '[X] has the same position as [Y].', 'The position of [X] is [Y]', 'The position of [X] is that of [Y].', 'A position of [Y] is held by [X].', 'The position is [Y] and [X].', 'The position is [Y] for [X].', 'There is a position of [Y] in [X].', 'The position of [X] and [Y] is [X] and [Y].', '[X] has the position of [Y].', 'There is a position of [Y] for [X].', '[X] holds the position of [Y].', 'There is a position of [X] and a position of [Y].', '[Y] is the position that [X] is in.', 'There is a position of [Y] and [X].', '[X] is in the middle of [Y].', 'There is a position of [Y] that [X] has.', '[X] has the position [Y].', 'The position of [Y] is called [X].', '[X] is the position of [Y].', 'There is a position called [Y].', 'The position of x is [Y].', "There's a position of [Y] for [X]."]
# ['The field of [Y] is being worked on by [X].', 'The field of [Y] is worked by [X].', '[X] works in the field of [Y].', 'The field of [Y] is worked on by [X].', 'The field of [Y] is being worked in by [X].', '[X] is in the field of [Y].', 'In the field of [Y], [X] works.', 'The field of [Y] is worked in by [X].', 'There is a person working in the field of [Y].', '[X] is working in the field of [Y].', 'A person works in the field of [Y].', 'The field of [Y] is where [X] works.', 'The field of [Y] has [X] working in it.', '[X] does work in the field of [Y].', '[X] is involved in the field of [Y].', '[X] works in the field of [Y]', 'The field of [Y] is occupied by [X].', 'There is a person in the field of [Y].', "[Y] is [X]'s field.", '[Y] is the field that [X] works in.', 'The field of [Y] is what [X] works in.', 'There is a field of [Y] that [X] works in.', 'The field of [Y] is being worked upon by [X].', '[Y] is a field that [X] works in.', '[X] is employed in the field of [Y].', 'He works in the field of [Y].', '[Y] is the field [X] works in.', '[X] works in [Y].', "[Y] is [X]'s field of work.", '[X] works in a field called [Y].', 'The person works in the field of [Y].', 'The field of [Y] is worked upon by [X].', "The field of [Y] is [X]'s field.", '[Y] is the field of [X].', 'The field of [Y] is done by [X].', 'The field of [Y] was worked by [X].', '[X] works in the area of [Y].', '[X] works in the [Y] field.', '[X] works in the field.', 'There is a field of [Y].']
# ['[Y] is the name of [X].', '[X] is named after [Y].', '[Y] is named after [X].', 'The name [X] is named after [Y].', 'The name [X] is after [Y].', "It's called [X] because it's named after [Y].", '[X] is named after [Y]', '[Y] is followed by [X].', '[Y] is what [X] is named after.', "It's called [X] after [Y].", '[X] was named after [Y].', '[Y] and [X] are both named after the same person.', '[Y] is the name of the person named [X].', "It's called [X] because it is named after [Y].", '[Y] was named after [X].', '[Y] is the name [X] is named after.', '[Y] is the name [X] is given.', '[X] is named after a person.', '[Y] and [X] are both named after it.', 'The name [X] is after the [Y].', '[Y] and [X] are both named after the same thing.', '[Y] is known as [X].', 'The name [X] is derived from the Greek word for [Y].', 'It is called [X] after [Y].', '[Y] is the name [X] is given after.', '[X] is named after another person.', '[Y] is the name that [X] is named after.', 'The name [X] is taken after [Y].', 'The name is [X] after [Y].', 'The person is named [X] after [Y].', '[Y] is referred to as [X].', 'The name [X] is derived from the Greek word [Y].', 'The name after [Y] is [X].', 'The name [X] is taken from the Greek word for [Y].', 'It is named [X] after [Y].', 'The name [X] is a combination of the letters [Y] and [X].', 'The name [X] is named after the [Y].', 'After [Y], [X] is named.', 'The name [X] is derived from [Y].', 'It is named after [Y].']
# ['[Y] has [X] as a member.', '[Y] has a member named [X].', '[Y] has a member called [X].', 'A member of [Y] is [X].', '[X] is not a member of [Y].', '[Y] is a group of people with the same name.', 'The person is a member of [Y].', 'There is a person named [X] who is a member of [Y].', '[Y] has a member known as [X].', '[Y] has one member who is also a member of [X].', 'There is a person who is a member of [Y].', '[Y] is a group with [X] as a member.', '[Y] has one member named [X].', '[Y] has x as a member.', '[Y] has a member who is called [X].', '[Y] has one member called [X].', "Y's member is [X].", 'The member of [Y] is [X].', '[Y] has a member who is [X].', '[X] is a member of a group.', 'There is a person named [X] who is also a member of [Y].', '[X] is a member of [Y].', 'A person is a member of [Y].', '[X] is a member of a group called [Y].', '[Y] has a member who is also a member of [X].', '[Y] has [X] in it.', '[Y] has a member who is also known as [X].', 'There is a member called [X].', '[Y] has an individual named [X].', 'There is a person named [X] in this group.', 'There is a person named [X] who is in a group called [Y].', 'A person named [X] is a member of a group called [Y].', 'There is a person named [X] who is a part of [Y].', 'Someone is a member of [Y].', '[Y] is a group of people.', 'There is a person named [X] who is a member of the group [Y].', '[Y] is made up of [X] and others.', 'There is a member named [X].', 'There is a person named [X] who is a member of a group called [Y].', 'You are a member of [X].']
# ['[X] used to work in [Y].', '[Y] was where [X] used to work.', 'In [Y], [X] used to work.', 'The person used to work in [Y].', '[X] worked in [Y].', '[Y] used to be where [X] used to work.', '[X] used to work there.', 'There was a time when [X] used to work in [Y].', 'It was [X] who used to work in [Y].', 'He used to work in [Y].', '[X] was once employed in [Y].', '[X] used to work for [Y].', 'There was a time when [X] worked in [Y].', 'It used to be that [X] worked in [Y].', "[Y] used to be [X]'s place of employment.", '[X] was employed in [Y].', 'The man used to work in [Y].', 'They used to work in [Y].', 'In the past, [X] used to work in [Y].', '[X] was used to work in [Y].', 'In the past, [X] worked in [Y].', '[Y] is where [X] used to work.', '[Y] used to be where [X] worked.', '[X] once worked in [Y].', '[X] used to work at [Y].', 'I used to work in [Y].', 'People used to work in [Y].', '[X] used to work in [Y]', '[X] used to work in the same place as [Y].', 'I used to work for [X] in [Y].', '[X] used to work in another place.', "[Y] used to be [X]'s place of work.", 'The guy used to work in [Y].', '[X] used to work in the same building as [Y].', 'In [Y], [X] worked.', '[X] used to work in a building.', 'The person used to work there.', '[X] was a worker in [Y].', '[X] used to work in another location.', '[X] had a job in [Y].']
# ['[Y] is the producer of [X].', '[Y] makes [X].', '[Y] produces [X].', '[X] is made by [Y].', 'The production of [X] is done by [Y].', '[Y] produced [X].', '[Y] is the creator of [X].', '[Y] is the manufacturer of [X].', '[Y] is responsible for producing [X].', '[Y] is the maker of [X].', '[X] is produced by another person.', '[X] is manufactured by [Y].', '[Y] is the production company for [X].', '[Y] is the company that produces [X].', 'The producer of [X] is [Y].', '[Y] is the company that produced [X].', '[Y] is the company that makes [X].', '[X] was produced by [Y].', '[Y] is how [X] is produced.', '[Y] is the person who produced [X].', '[X] is created by [Y].', "It's produced by [Y].", '[Y] is the main producer of [X].', 'It is produced by [Y].', 'The production of [X] is by [Y].', '[Y] creates [X].', '[X] is produced by [Y].', 'The [X] is made by [Y].', '[X] is produced by another.', '[Y] is the producer.', '[Y] is the person who produces [X].', '[Y] is the producer of x.', '[X] is a product of [Y].', '[X] is a creation of [Y].', 'The [X] is produced by [Y].', '[Y] is how [X] is made.', '[Y] is the person who makes [X].', '[X] is produced by other people.', '[X] is made by another person.', '[X] is produced by someone else.']
# ['[X] is a profession.', '[X] is a [Y] in a profession.', 'By profession, [X] is a [Y].', "It's a [Y] by profession.", 'By profession [X] is a [Y].', 'A [Y] by profession is [X].', 'There is a [Y] by profession.', '[X] is a profession', 'The profession [X] is by is [Y].', '[X] is a [Y] profession.', 'A [Y] is a [X] by profession.', '[X] is a [Y] by profession.', '[Y] is a profession.', 'It is a [Y] by profession.', 'The profession of [X] is [Y].', '[Y] is a profession for [X].', '[X] is a person in a profession.', 'There is a profession called [X].', 'A [Y] is a [X].', '[X] is a [Y] by a profession.', 'A [Y] is a [X] by a profession.', 'A [Y] is a [X] in a profession.', '[X] is a professional.', 'The profession is [X].', '[X] is a [Y] in the same way that [Y] is a [Y] in the same profession.', 'There is a [Y] and a [X].', 'Is [X] a [Y] by profession?', '[X] is a [Y] in the same way that [Y] is a [Y] in a profession.', 'By profession is [X] a [Y].', 'A [Y] is [X] by profession.', '[X] is a [Y].', 'A [Y] is a [X] in this case.', '[X] is a [Y] by profession', 'There is a [Y] and a [X] in this picture.', '[X] is a [Y] because of his profession.', '[Y] is the profession [X] is by.', 'By profession, [X] is [Y].', 'By profession [X] is [Y].', '[X] is a [Y] by occupation.', '[Y] is a [Y] by profession.']
# ['[Y] is the original language of [X].', 'The original language of [X] is [Y].', 'The original language is [Y].', '[Y] was the original language of [X].', 'The original language of [X] was [Y].', '[Y] is the original language for [X].', "X's original language is [Y].", 'The language of [X] is [Y].', 'The original language for [X] is [Y].', 'The original language was [Y].', 'The first language of [X] is [Y].', '[Y] is the language of [X].', 'The original language in [X] is [Y].', 'The original language of [X] is called [Y].', '[Y] is the original language.', 'The language of [X] is called [Y].', 'The [Y] is the original language of [X].', 'The language of [X] was originally called [Y].', '[Y] is the first language of [X].', '[Y] is the original language of [X]', 'The original language for [X] was [Y].', "It's the original language of [X].", '[Y] is what the original language of [X] is.', 'The initial language of [X] is [Y].', "X's original language was [Y].", 'It is the original language of [X].', 'The original language of [X] is [Y]', 'The original language is called [Y].', 'The original language of [X] was called [Y].', '[Y] was the original language for [X].', '[Y] is the original language ofX.', '[Y] is the original Language of [X].', '[Y] is the main language of [X].', '[Y] is the original language of x.', 'The original language in [X] was [Y].', 'The [Y] language is the original one for [X].', '[Y] is the original language in [X].', '[X] is written in [Y].', 'There is a language called [Y] in [X].', 'The language of [X] was [Y].']
# ['[Y] is the owner of [X].', '[Y] owns [X].', '[X] is owned by another person.', "[Y] is [X]'s owner.", '[X] is owned by [Y].', 'The owner of [X] is [Y].', '[Y] owned [X].', '[X] is owned by another.', '[Y] and [X] are both owned by the same person.', '[Y] and [X] are owned by the same person.', '[Y] is the shareholder of [X].', '[Y] is owner of [X].', '[X] is owned by someone else.', '[Y] is one of the owners of [X].', '[Y] is the person who owns [X].', 'The owners of [X] are [Y] and [X].', '[Y] has ownership of [X].', '[Y] is owned by [X].', '[Y] is the proprietor of [X].', '[Y] is the owner of x.', '[Y] is theowner of [X].', 'A person is owned by another person.', '[Y] is the one who owns [X].', '[Y] is the owner of [X]', '[Y] is the owners of [X].', '[Y] is the controlling shareholder of [X].', "[Y] is [X]'s shareholder.", '[Y] is the owner ofX.', '[Y] and [X] are owned by each other.', '[X] is owned by [Y]', '[X] is a company owned by [Y].', '[X] is owned by a person named [Y].', '[X] is a company owned by another person.', 'The [X] is owned by [Y].', '[X] is owned by a different person.', "[Y] is [X]'s controlling shareholder.", '[Y] is the owner of [X].', '[Y] is a shareholder in [X].', '[X] is owned by other people.', '[X] is owned by another individual.']
# ['The show was originally aired on [Y].', '[X] was on [Y].', '[X] was first aired on [Y].', '[Y] was where [X] was originally aired.', 'The show was first aired on [Y].', '[X] was broadcasted on [Y].', 'It was first aired on [Y].', 'On [Y], [X] was aired.', '[X] was previously aired on [Y].', 'It was aired on [Y].', 'In the past, [X] was aired on [Y].', 'It was originally aired on [Y].', '[X] used to be aired on [Y].', '[X] was broadcast on [Y].', '[Y] originally aired [X].', 'The show was aired on [Y].', '[Y] was where [X] was first aired.', '[Y] was the place where [X] was originally aired.', '[X] used to be on [Y].', '[Y] aired [X].', '[X] was aired on [Y].', 'There was a show on [Y] called [X].', 'On [Y], there was a show called [X].', '[X] was first broadcasted on [Y].', 'The show was on [Y].', 'The show was originally on [Y].', '[X] was once aired on [Y].', 'The show was originally broadcasted on [Y].', '[Y] was the place where [X] was first aired.', '[X] aired on [Y].', 'On [Y], there was a program called [X].', 'There was a show called [X] on [Y].', 'It was on [Y].', '[X] was originally aired on [Y].', 'There was a show on [Y] that was called [X].', 'There was a show called [X] that aired on [Y].', 'There was a show called [X] that was aired on [Y].', 'It was broadcasted on [Y].', 'In the past, [X] was broadcasted on [Y].', '[X] originally aired on [Y].']
# ['It was written in [Y].', '[Y] was where [X] was written.', 'The word [X] was written in [Y].', '[X] was written in [Y].', '[Y] is where [X] was written.', 'The letter [X] was written in [Y].', 'The words [X] and [Y] were written in the same place.', 'The letter [X] was written in the same place as the letter [Y].', 'In [Y], [X] was written.', '[X] is written in [Y].', '[Y] was written in [X].', '[Y] was the language that [X] was written in.', 'The word was written in [Y].', '[X] was written in a different language.', '[Y] was the place where [X] was written.', '[Y] was where the letter [X] was written.', '[X] was written in the same language as [Y].', '[Y] was used to write [X].', 'The text was written in [Y].', 'The letter [X] was written in the letter [Y].', '[X] was written in the same place as [Y].', 'The words [X] and [Y] were written in the same language.', '[X] was written in another language.', '[Y] was where the word [X] was written.', 'The letters [X] were written in [Y].', 'The words [X] were written in [Y].', 'The letter [X] was written in the middle of the letter [Y].', 'The word [X] is written in [Y].', 'The name [X] was written in [Y].', 'There was a letter [X] written in [Y].', 'The word [X] was written in the same language as [Y].', 'The letter [X] is written in [Y].', 'The letter [X] was written in the same language as the letter [Y].', 'The letter [X] was written in the letters [Y].', 'The [X] was written in [Y].', 'There was a word written in [Y].', '[X] was written in [Y]', 'The letter [X] was written in the alphabet.', '[Y] was the language of [X].', 'The word [X] was written in the same place as [Y].']
# ['The capital of [X] is [Y].', '[Y] is the capital of [X].', 'The capital is [Y].', '[X] has a capital of [Y].', 'The capital of [Y] is [X].', 'The capital of [X] is [Y]', '[X] is the capital of [Y].', "X's capital is [Y].", 'The capital of [X] is called [Y].', 'The name of the capital of [X] is [Y].', 'The capital of [X] is the same as the capital of [Y].', 'There is a capital of [Y] in [X].', 'The capital of[X] is [Y].', 'There is a capital of [Y].', 'The capital city of [X] is [Y].', 'The capital is [Y] in [X].', '[X] has a capital [Y].', 'The capital in [X] is [Y].', 'The capital of [X] is the letter [Y].', 'There is a capital in [X].', 'It is the capital of [X].', 'The name of the capital is [Y].', 'The capital of [X] is [Y].', "It's the capital of [X].", 'The capital of [X] is also called [Y].', 'There is a capital [Y] in [X].', "The capital of [X] is [Y], that's right.", 'A capital of [X] is [Y].', 'The capital of [X] is the [Y].', 'The capital of [X] is zero.', '[X] is a capital letter [Y].', '[Y] is the capital city of [X].', 'There is a capital of [X].', 'The capital of x is [Y].', 'The capital of the entity is [Y].', 'The capital of [X] was [Y].', 'The capital for [X] is [Y].', '[Y] is the capital of [X]', 'The capital of [X] is a letter [Y].', '[Y] is the capital ofX.']
# ['A [Y] is a [X].', '[X] is a letter [Y].', '[X] is a [Y].', 'There is a [Y] and a [X].', "That's right, [X] is a [Y].", 'A [Y] is [X].', '[X] and [Y] are the same thing.', '[X] is the same as [Y].', "It's a [Y], [X] is a [Y].", "It's a [Y] if [X] is a [Y].", '[Y] is a letter [X] is a letter [Y].', 'The letters [X] and [Y] are pronounced the same.', 'The letters [X] and [Y] are related.', "It's a [Y] because [X] is a [Y].", 'There is a [Y] and [X].', 'The letters [X] and [Y] correspond to the same thing.', 'The letters [X] and [Y] are the same.', '[Y] is a letter [X].', 'The letter [X] is a letter [Y].', 'A [Y] and [X] are the same thing.', 'There is an [X] and a [Y].', "There's a [Y] and a [X].", '[X] and [Y] are the same.', 'The letters [X] and [Y] are synonymous.', '[X] is not a [Y].', 'There is a [Y] and an [X].', '[X] is a digit.', 'The letter [X] is a [Y].', 'There is a [Y] and a [X] in this picture.', 'The letters [X] and [Y] are the same thing.', 'The letters [Y] and [X] are the same.', 'There is an [X] and an [Y].', '[X] and [Y] are the same color.', "It's a [Y] if [X] is it.", '[X] is a symbol for [Y].', "It's a [Y] with [X].", 'The letters [Y] and [X] are related.', 'A [Y] is an [X].', 'There is a [Y] in [X].', 'The letters [X] and [Y] are not the same.']
# ['[Y] is the developer of [X].', '[X] was developed by [Y].', '[Y] is the creator of [X].', '[Y] developed [X].', '[Y] is the person who developed [X].', '[Y] is the one who developed [X].', '[Y] created [X].', '[Y] was the one who developed [X].', '[X] was created by [Y].', '[Y] has developed [X].', '[Y] is responsible for the development of [X].', '[Y] is the author of [X].', '[Y] is responsible for the creation of [X].', 'The [X] was developed by [Y].', 'The person who developed [X] is [Y].', '[Y] is responsible for developing [X].', '[Y] is the one who created [X].', '[Y] develops [X].', '[Y] is the person who created [X].', '[X] is created by [Y].', '[Y] was the developer of [X].', 'The [X] is developed by [Y].', 'The [X] is created by [Y].', '[Y] is responsible for [X].', 'It was developed by [Y].', '[Y] was responsible for the development of [X].', '[X] is developed by another person.', 'The person who developed [X] was [Y].', '[X] has been developed by [Y].', '[X] was developed by another person.', '[Y] is the one that developed [X].', '[Y] is the originator of [X].', '[Y] and [X] are the two people who developed [X].', '[Y] is behind [X].', '[Y] came up with the idea of [X].', '[Y] came up with [X].', '[Y] and [X] are related.', '[Y] is how [X] is developed.', '[Y] is the person who develops [X].', '[Y] was responsible for developing [X].']
# ['[X] works for [Y].', '[Y] works for [X].', '[X] is employed by [Y].', '[X] is for [Y].', '[Y] is worked for by [X].', '[X] works for another person.', "It's [X] that works for [Y].", '[X] works for someone else.', 'A person works for another person.', '[X] works for [Y]', 'It is [X] that works for [Y].', '[X] is used for [Y].', '[X] does work for [Y].', '[X] is a worker for [Y].', 'It is [X] who works for [Y].', '[X] has a job for [Y].', '[X] is able to work for [Y].', '[Y] has [X] working for it.', 'For [Y], [X] works.', 'The person works for [Y].', '[X] works for another.', '[X] is employed for [Y].', "[Y] is [X]'s work.", '[X] is an employee of [Y].', 'The person works for the other person.', '[Y] requires [X] to work for it.', '[X] is good for [Y].', 'The person works for another person.', '[X] works for a different person.', '[X] works for other people.', '[X] works for the other person.', '[X] works with [Y].', '[Y] has [X] working for him.', 'The [X] works for [Y].', "[Y] is [X]'s job.", '[X] does [Y] work.', '[Y] works with [X].', '[X] works for a person.', 'He works for [Y].', 'I work for [Y].']
# ['[X] used to speak in [Y].', 'In [Y], [X] used to communicate.', '[X] used to communicate in [Y].', '[Y] was used to communicate with [X].', '[X] used to talk in [Y].', 'There was a time when [X] used to communicate in [Y].', '[X] used to say something in [Y].', '[X] communicated in [Y].', '[X] used to communicate with [Y].', 'In the past, [X] used to communicate in [Y].', 'It was used to communicate in [Y].', '[X] used to communicate in another language.', 'It used to be that [X] used to communicate in [Y].', '[Y] was the language [X] used to communicate in.', 'The person used to communicate in [Y].', 'A person used to communicate in [Y].', '[Y] is where [X] used to communicate.', 'There used to be a way for [X] to communicate in [Y].', '[X] used to use [Y].', '[X] used to use [Y] to communicate.', 'They used to communicate in [Y].', '[X] used to communicate in [Y]', 'It used to be that [X] communicated in [Y].', '[Y] used to be used to communicate with [X].', '[X] was able to communicate in [Y].', 'There used to be a way for [X] to communicate with [Y].', '[X] used to communicate using [Y].', '[Y] was where [X] used to communicate.', '[X] used to send and receive messages in [Y].', 'It was possible to communicate in [Y].', '[X] used to communicate in a different language.', 'In [Y], [X] used to talk.', 'In the past, [X] communicated in [Y].', 'In [Y], [X] used to speak.', '[Y] used to communicate with [X].', 'There used to be a way for [X] to communicate.', '[X] used to communicate with [Y] in another language.', '[X] used to speak in [Y]', 'There was a time when [X] used to communicate with [Y].', '[X] and [Y] used to communicate.']

# %%
subset_dict['P1001']
# Out:
#                                         uuid obj_uri obj_label  sub_uri  \
# 707048  e97e884a-3ed6-4933-8665-29e8834ae811     Q17     Japan  Q274948
#
#                       sub_label predicate_id     sub_surface obj_surface  \
# 707048  Prime Minister of Japan        P1001  Prime Minister       Japan
#
#                                           masked_sentence  \
# 707048  The Twenty-One Demands (Japanese: 対華21ヶ条要求, Ta...
#
#                             template                  template_negated  \
# 707048  [X] is a legal term in [Y] .  [X] is not a legal term in [Y] .
#
#                           label  \
# 707048  applies to jurisdiction
#
#                                               description type  \
# 707048  the item (an institution, law, public office ....  N-M
#
#                                         generated_prompts
# 707048  [A legal term in [Y] is [X]., In [Y], [X] is a...

# %%
# Export/Import dict of prompt templates to json file
import json
from google.colab import drive
drive.mount('/content/drive')

fileName = 'paraphrased_prompt_templates_unfiltered.json'

# Serialize subset_dict as a json file
def exportJson(dict_to_export):
  out_dict = {r: {'orig_template': sub_df['template'].iloc[0], 'generated_prompts': sub_df['generated_prompts'].iloc[0]} for r, sub_df in dict_to_export.items() }
  with open("/content/drive/MyDrive/"+fileName, "w") as outfile:
      json.dump(out_dict, outfile)
      print("Exported json.")

exportJson(subset_dict)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Exported json.
#                                          uuid obj_uri  obj_label sub_uri  \
# 1072091  c5e5a6eb-b13d-4fb9-828f-b4ddfdbec71a    Q408  Australia     Q16
#
#         sub_label predicate_id sub_surface obj_surface  \
# 1072091    Canada         P530      Canada   Australia
#
#                                            masked_sentence  \
# 1072091  It is a multinational project involving resear...
#
#                                               template  \
# 1072091  [X] maintains diplomatic relations with [Y] .
#
#                                           template_negated  \
# 1072091  [X] does not maintain diplomatic relations wit...
#
#                        label                          description type  \
# 1072091  diplomatic relation  diplomatic relations of the country  N-M
#
#                                          generated_prompts
# 1072091  [[X] and [Y] have diplomatic relations., [X] h...

# %%
# Import pre-generated prompts from json file
def importJson():
  with open("/content/drive/MyDrive/"+fileName, "r") as f:
    data = json.load(f)
  return data
new_templates_dict = importJson()
new_templates_dict
# Out:
# {'P1001': {'generated_prompts': ['A legal term in [Y] is [X].',
#    'In [Y], [X] is a legal term.',
#    'There is a legal term called [X].',
#    "It's a legal term in [Y].",
#    '[X] is a legal term.',
#    'The legal term is [X].',
#    'A legal term is [X].',
#    'There is a legal term in [Y] called [X].',
#    'In [Y] there is a legal term called [X].',
#    'The legal term in [Y] is [X].',
#    '[Y] has a legal term called [X].',
#    'In [Y], the legal term is [X].',
#    'The legal term [X] is in [Y].',
#    'In [Y], there is a legal term called [X].',
#    'It is a legal term in [Y].',
#    'There is a legal term in [Y].',
#    'In [Y], the term [X] is a legal one.',
#    'There is a legal term called [X] in [Y].',
#    "There's a legal term in [Y] called [X].",
#    '[Y] is the legal term for [X].',
#    'In [Y], the term [X] is used as a legal term.',
#    'There is a legal term for [X].',
#    '[Y] is a legal term for [X].',
#    "There's a legal term called [X] in [Y].",
#    '[X] is a legal term in [Y].',
#    'In [Y], the term [X] is a legal term.',
#    'There is a legal term for [X] in [Y].',
#    'There is a legal term known as [X].',
#    'Legal terms in [Y] are [X] and [Y].',
#    '[Y] is a legal term called [X].',
#    "It's a legal term called [X] in [Y].",
#    '[X] is a legal word.',
#    '[Y] is a legal term.',
#    '[X] is a legal term',
#    'There is a legal term for that.',
#    'There is a legal term in [Y] that is called [X].',
#    'There is a legal term for it in [Y].',
#    'There are legal terms in [Y].',
#    '[Y] is a legal term that means [X].',
#    "It's a legal term called [X]."],
#   'orig_template': '[X] is a legal term in [Y] .'},
#  'P101': {'generated_prompts': ['The field of [Y] is being worked on by [X].',
#    'The field of [Y] is worked by [X].',
#    '[X] works in the field of [Y].',
#    'The field of [Y] is worked on by [X].',
#    'The field of [Y] is being worked in by [X].',
#    '[X] is in the field of [Y].',
#    'In the field of [Y], [X] works.',
#    'The field of [Y] is worked in by [X].',
#    'There is a person working in the field of [Y].',
#    '[X] is working in the field of [Y].',
#    'A person works in the field of [Y].',
#    'The field of [Y] is where [X] works.',
#    'The field of [Y] has [X] working in it.',
#    '[X] does work in the field of [Y].',
#    '[X] is involved in the field of [Y].',
#    '[X] works in the field of [Y]',
#    'The field of [Y] is occupied by [X].',
#    'There is a person in the field of [Y].',
#    "[Y] is [X]'s field.",
#    '[Y] is the field that [X] works in.',
#    'The field of [Y] is what [X] works in.',
#    'There is a field of [Y] that [X] works in.',
#    'The field of [Y] is being worked upon by [X].',
#    '[Y] is a field that [X] works in.',
#    '[X] is employed in the field of [Y].',
#    'He works in the field of [Y].',
#    '[Y] is the field [X] works in.',
#    '[X] works in [Y].',
#    "[Y] is [X]'s field of work.",
#    '[X] works in a field called [Y].',
#    'The person works in the field of [Y].',
#    'The field of [Y] is worked upon by [X].',
#    "The field of [Y] is [X]'s field.",
#    '[Y] is the field of [X].',
#    'The field of [Y] is done by [X].',
#    'The field of [Y] was worked by [X].',
#    '[X] works in the area of [Y].',
#    '[X] works in the [Y] field.',
#    '[X] works in the field.',
#    'There is a field of [Y].'],
#   'orig_template': '[X] works in the field of [Y] .'},
#  'P103': {'generated_prompts': ['[Y] is the native language of [X].',
#    'The native language of [X] is [Y].',
#    'The language of [X] is [Y].',
#    'The [Y] is the native language of [X].',
#    'The native language is [Y].',
#    "X's native language is [Y].",
#    'The native tongue of [X] is [Y].',
#    'The native language for [X] is [Y].',
#    '[Y] is the native language for [X].',
#    'The [Y] language is the native language of [X].',
#    '[Y] is the language of [X].',
#    '[Y] is a native language of [X].',
#    'There is a native language of [X].',
#    'The language [Y] is the native language of [X].',
#    '[Y] is the native Language of [X].',
#    'The native language of the people of [X] is [Y].',
#    '[Y] is the official language of [X].',
#    'The native language in [X] is [Y].',
#    '[Y] is the native language of [X]',
#    '[Y] is the native language ofX.',
#    'A native language of [X] is [Y].',
#    '[Y] is the native tongue of [X].',
#    '[X] is a native language of [Y].',
#    '[Y] is the native language in [X].',
#    'There is a native language for [X].',
#    '[Y] is the main language of [X].',
#    'The native language of the people is [Y].',
#    'The main language of [X] is [Y].',
#    '[Y] is the primary language of [X].',
#    '[Y] is the native language.',
#    'The native language of [X] is [Y]',
#    'The official language of [X] is [Y].',
#    '[Y] is the native language of the people of [X].',
#    'It is the native language of [X].',
#    'The native Language of [X] is [Y].',
#    '[Y] is the native language of x.',
#    '[Y] is the native language of the [X] race.',
#    'The [Y] language is the native one of [X].',
#    'The native language of [Y] is [X].',
#    '[X] is a language with a native language of [Y].'],
#   'orig_template': 'The native language of [X] is [Y] .'},
#  'P106': {'generated_prompts': ['[X] is a profession.',
#    '[X] is a [Y] in a profession.',
#    'By profession, [X] is a [Y].',
#    "It's a [Y] by profession.",
#    'By profession [X] is a [Y].',
#    'A [Y] by profession is [X].',
#    'There is a [Y] by profession.',
#    '[X] is a profession',
#    'The profession [X] is by is [Y].',
#    '[X] is a [Y] profession.',
#    'A [Y] is a [X] by profession.',
#    '[X] is a [Y] by profession.',
#    '[Y] is a profession.',
#    'It is a [Y] by profession.',
#    'The profession of [X] is [Y].',
#    '[Y] is a profession for [X].',
#    '[X] is a person in a profession.',
#    'There is a profession called [X].',
#    'A [Y] is a [X].',
#    '[X] is a [Y] by a profession.',
#    'A [Y] is a [X] by a profession.',
#    'A [Y] is a [X] in a profession.',
#    '[X] is a professional.',
#    'The profession is [X].',
#    '[X] is a [Y] in the same way that [Y] is a [Y] in the same profession.',
#    'There is a [Y] and a [X].',
#    'Is [X] a [Y] by profession?',
#    '[X] is a [Y] in the same way that [Y] is a [Y] in a profession.',
#    'By profession is [X] a [Y].',
#    'A [Y] is [X] by profession.',
#    '[X] is a [Y].',
#    'A [Y] is a [X] in this case.',
#    '[X] is a [Y] by profession',
#    'There is a [Y] and a [X] in this picture.',
#    '[X] is a [Y] because of his profession.',
#    '[Y] is the profession [X] is by.',
#    'By profession, [X] is [Y].',
#    'By profession [X] is [Y].',
#    '[X] is a [Y] by occupation.',
#    '[Y] is a [Y] by profession.'],
#   'orig_template': '[X] is a [Y] by profession .'},
#  'P108': {'generated_prompts': ['[X] works for [Y].',
#    '[Y] works for [X].',
#    '[X] is employed by [Y].',
#    '[X] is for [Y].',
#    '[Y] is worked for by [X].',
#    '[X] works for another person.',
#    "It's [X] that works for [Y].",
#    '[X] works for someone else.',
#    'A person works for another person.',
#    '[X] works for [Y]',
#    'It is [X] that works for [Y].',
#    '[X] is used for [Y].',
#    '[X] does work for [Y].',
#    '[X] is a worker for [Y].',
#    'It is [X] who works for [Y].',
#    '[X] has a job for [Y].',
#    '[X] is able to work for [Y].',
#    '[Y] has [X] working for it.',
#    'For [Y], [X] works.',
#    'The person works for [Y].',
#    '[X] works for another.',
#    '[X] is employed for [Y].',
#    "[Y] is [X]'s work.",
#    '[X] is an employee of [Y].',
#    'The person works for the other person.',
#    '[Y] requires [X] to work for it.',
#    '[X] is good for [Y].',
#    'The person works for another person.',
#    '[X] works for a different person.',
#    '[X] works for other people.',
#    '[X] works for the other person.',
#    '[X] works with [Y].',
#    '[Y] has [X] working for him.',
#    'The [X] works for [Y].',
#    "[Y] is [X]'s job.",
#    '[X] does [Y] work.',
#    '[Y] works with [X].',
#    '[X] works for a person.',
#    'He works for [Y].',
#    'I work for [Y].'],
#   'orig_template': '[X] works for [Y] .'},
#  'P127': {'generated_prompts': ['[Y] is the owner of [X].',
#    '[Y] owns [X].',
#    '[X] is owned by another person.',
#    "[Y] is [X]'s owner.",
#    '[X] is owned by [Y].',
#    'The owner of [X] is [Y].',
#    '[Y] owned [X].',
#    '[X] is owned by another.',
#    '[Y] and [X] are both owned by the same person.',
#    '[Y] and [X] are owned by the same person.',
#    '[Y] is the shareholder of [X].',
#    '[Y] is owner of [X].',
#    '[X] is owned by someone else.',
#    '[Y] is one of the owners of [X].',
#    '[Y] is the person who owns [X].',
#    'The owners of [X] are [Y] and [X].',
#    '[Y] has ownership of [X].',
#    '[Y] is owned by [X].',
#    '[Y] is the proprietor of [X].',
#    '[Y] is the owner of x.',
#    '[Y] is theowner of [X].',
#    'A person is owned by another person.',
#    '[Y] is the one who owns [X].',
#    '[Y] is the owner of [X]',
#    '[Y] is the owners of [X].',
#    '[Y] is the controlling shareholder of [X].',
#    "[Y] is [X]'s shareholder.",
#    '[Y] is the owner ofX.',
#    '[Y] and [X] are owned by each other.',
#    '[X] is owned by [Y]',
#    '[X] is a company owned by [Y].',
#    '[X] is owned by a person named [Y].',
#    '[X] is a company owned by another person.',
#    'The [X] is owned by [Y].',
#    '[X] is owned by a different person.',
#    "[Y] is [X]'s controlling shareholder.",
#    '[Y] is the owner of [X].',
#    '[Y] is a shareholder in [X].',
#    '[X] is owned by other people.',
#    '[X] is owned by another individual.'],
#   'orig_template': '[X] is owned by [Y] .'},
#  'P1303': {'generated_prompts': ['[X] plays [Y].',
#    '[Y] plays [X].',
#    '[X] is playing [Y].',
#    '[Y] is played by [X].',
#    '[X] plays [Y]',
#    '[X] is in a game with [Y].',
#    '[X] plays a game.',
#    '[Y] is being played by [X].',
#    'There is a game between [X] and [Y].',
#    '[X] and [Y] are playing.',
#    'There is a game called [X] plays [Y].',
#    '[X] and [Y] play each other.',
#    'A person plays a game.',
#    'The [X] plays the [Y].',
#    'The player [X] plays the game [Y].',
#    'The player [X] plays [Y].',
#    '[Y] is playing [X].',
#    'The person playing [Y] is [X].',
#    '[X] is in a game of [Y].',
#    '[X] and [Y] are playing a game.',
#    'The person is playing [Y] and [X] is playing [X].',
#    'The person plays [Y].',
#    'There is a game of [X] plays [Y].',
#    '[X] plays [Y] in a game.',
#    'There is a game of [Y] and [X].',
#    'The player [X] plays the other player [Y].',
#    '[X] is in a game against [Y].',
#    'The player [X] plays a game.',
#    'A person plays a board game.',
#    'A man plays a game.',
#    '[X] is against [Y].',
#    'A player plays a game.',
#    "It's [X] versus [Y].",
#    'The [X] plays [Y].',
#    'The person playing [Y] plays [X].',
#    'The person plays a game.',
#    '[X] plays [Y].',
#    'The person is playing [Y] and [X] plays [X].',
#    'The person is playing [Y] and [X].',
#    '[X] is playing a game.'],
#   'orig_template': '[X] plays [Y] .'},
#  'P131': {'generated_prompts': ['[Y] is where [X] is located.',
#    '[Y] is the location of [X].',
#    'The location of [X] is in [Y].',
#    '[X] is in [Y].',
#    'There is a place called [X] located in [Y].',
#    'The location of [X] is [Y].',
#    'There is a place called [X] in [Y].',
#    '[Y] is located in [X].',
#    'You can find [X] in [Y].',
#    '[X] is located in [Y].',
#    'In [Y] is where [X] is located.',
#    '[Y] is the location for [X].',
#    '[Y] is the place where [X] is located.',
#    '[X] is in the same location as [Y].',
#    'In [Y], there is [X].',
#    'The place called [X] is located in [Y].',
#    '[Y] is where [X] is.',
#    '[X] is in the same area as [Y].',
#    '[X] is in the same place as [Y].',
#    'There is [X] in [Y].',
#    'There is [X] located in [Y].',
#    'It is located in [Y].',
#    'In [Y] is the location of [X].',
#    'There is a street called [X] located in [Y].',
#    '[Y] has [X] located in it.',
#    'There is a place named [X] located in [Y].',
#    'There is a street called [X] in [Y].',
#    'There is a person located in [Y].',
#    '[X] is in the same city as [Y].',
#    '[X] can be found in [Y].',
#    '[X] is in the city of [Y].',
#    'There is a street named [X] located in [Y].',
#    '[X] is located in the same location as [Y].',
#    '[X] is located in the same area as [Y].',
#    'There is a place named [X] in [Y].',
#    'A person is located in [Y].',
#    '[X] is located in the same place as [Y].',
#    '[Y] has [X] in it.',
#    "It's located in [Y].",
#    'There is a person in [Y].'],
#   'orig_template': '[X] is located in [Y] .'},
#  'P136': {'generated_prompts': ['[X] plays music.',
#    '[Y] music is played by [X].',
#    '[X] is playing music.',
#    '[Y] music is being played by [X].',
#    '[Y] music plays in the background.',
#    '[X] plays a song.',
#    '[X] is playing [Y] music.',
#    'A person plays music.',
#    '[X] plays music',
#    '[Y] music plays as [X] plays it.',
#    '[X] plays [Y] music.',
#    "[Y] music plays in [X]'s headphones.",
#    '[Y] music is plays by [X].',
#    'The person plays music.',
#    'The person plays [Y] music.',
#    '[Y] is the music that [X] plays.',
#    "[Y] plays [X]'s music.",
#    '[Y] music played by [X].',
#    'The [X] plays music.',
#    "[Y] music plays in [X]'s ears.",
#    '[X] plays music for others.',
#    'The person is playing [Y] music.',
#    '[Y] music is played by [X]',
#    "[Y] music plays in [X]'s music player.",
#    '[Y] plays [X] music.',
#    '[Y] is the music [X] plays.',
#    "[Y] music plays in [X]'s ear.",
#    '[X] is a musician.',
#    '[Y] music plays in the background as [X] plays it.',
#    '[Y] is played by [X].',
#    '[X] plays an instrument.',
#    '[X] plays some music.',
#    '[X] plays the music.',
#    '[X] plays music for other people.',
#    '[Y] is played by [X] when he plays music.',
#    'There is a person playing [Y] music.',
#    '[Y] is played by [X] as he plays music.',
#    "[Y] music plays in [X]'s head.",
#    'A man plays music.',
#    "[Y] music plays on [X]'s headphones."],
#   'orig_template': '[X] plays [Y] music .'},
#  'P1376': {'generated_prompts': ['The capital of [Y] is [X].',
#    '[Y] is the capital of [X].',
#    'The capital is [X].',
#    'The capital of [Y] is called [X].',
#    '[X] is the capital of [Y].',
#    "Y's capital is [X].",
#    'The capital of [Y] is x.',
#    'The capital of [Y] is known as [X].',
#    'The capital of the [Y] is [X].',
#    "It's the capital of [Y].",
#    'It is the capital of [Y].',
#    'There is a capital [X] and a capital [Y].',
#    '[Y] is the capital of [X]',
#    'The capital of [Y] is [X].',
#    '[Y] is the capital city of [X].',
#    '[Y] has the capital [X].',
#    'The capital is called [X].',
#    '[Y] is the capital.',
#    'The capital city of [Y] is [X].',
#    '[Y] has a capital [X].',
#    '[Y] is a capital of [X].',
#    '[Y] has a capital of [X].',
#    "[Y] is [X]'s capital.",
#    'There is a capital [X].',
#    'the capital of [Y] is [X].',
#    'There is a capital of [Y].',
#    'The capital of [Y] is named [X].',
#    '[Y] is the capital of [X].',
#    '[X] is the capital of [Y]',
#    'The capital of [Y] is [X]',
#    '[Y] is the capital ofX.',
#    '[Y] has [X] as its capital.',
#    '[Y] has [X] as the capital.',
#    'The capital of [Y] was [X].',
#    'The capital [Y] is [X].',
#    'The capital of [X] is [Y].',
#    '[Y] is the capital of x.',
#    'A capital of [Y] is [X].',
#    '[Y] is capital of [X].',
#    '[Y] is the capital of the universe.'],
#   'orig_template': '[X] is the capital of [Y] .'},
#  'P138': {'generated_prompts': ['[Y] is the name of [X].',
#    '[X] is named after [Y].',
#    '[Y] is named after [X].',
#    'The name [X] is named after [Y].',
#    'The name [X] is after [Y].',
#    "It's called [X] because it's named after [Y].",
#    '[X] is named after [Y]',
#    '[Y] is followed by [X].',
#    '[Y] is what [X] is named after.',
#    "It's called [X] after [Y].",
#    '[X] was named after [Y].',
#    '[Y] and [X] are both named after the same person.',
#    '[Y] is the name of the person named [X].',
#    "It's called [X] because it is named after [Y].",
#    '[Y] was named after [X].',
#    '[Y] is the name [X] is named after.',
#    '[Y] is the name [X] is given.',
#    '[X] is named after a person.',
#    '[Y] and [X] are both named after it.',
#    'The name [X] is after the [Y].',
#    '[Y] and [X] are both named after the same thing.',
#    '[Y] is known as [X].',
#    'The name [X] is derived from the Greek word for [Y].',
#    'It is called [X] after [Y].',
#    '[Y] is the name [X] is given after.',
#    '[X] is named after another person.',
#    '[Y] is the name that [X] is named after.',
#    'The name [X] is taken after [Y].',
#    'The name is [X] after [Y].',
#    'The person is named [X] after [Y].',
#    '[Y] is referred to as [X].',
#    'The name [X] is derived from the Greek word [Y].',
#    'The name after [Y] is [X].',
#    'The name [X] is taken from the Greek word for [Y].',
#    'It is named [X] after [Y].',
#    'The name [X] is a combination of the letters [Y] and [X].',
#    'The name [X] is named after the [Y].',
#    'After [Y], [X] is named.',
#    'The name [X] is derived from [Y].',
#    'It is named after [Y].'],
#   'orig_template': '[X] is named after [Y] .'},
#  'P140': {'generated_prompts': ['[X] is a member of the [Y] religion.',
#    '[X] is affiliated with the [Y] religion.',
#    'The [Y] religion is affiliated with [X].',
#    '[X] is associated with the [Y] religion.',
#    '[X] is affiliated with a religion.',
#    '[X] is related to the [Y] religion.',
#    'The [Y] religion is associated with [X].',
#    'The [Y] religion has [X] as a member.',
#    'The [Y] religion has [X] as an affiliated member.',
#    '[X] is part of the [Y] religion.',
#    '[X] is a part of the [Y] religion.',
#    'The [Y] religion has an affiliation with [X].',
#    '[X] is connected to the [Y] religion.',
#    'The [Y] religion has [X] affiliated with it.',
#    'A person named [X] is affiliated with the [Y] religion.',
#    'The [Y] religion has an affiliated person named [X].',
#    'There is a person affiliated with the [Y] religion.',
#    '[X] has an affiliation with the [Y] religion.',
#    '[X] is linked to the [Y] religion.',
#    'The [Y] religion has an affiliated person called [X].',
#    'The [Y] religion has a member named [X].',
#    'The [Y] religion has a person named [X].',
#    '[X] is an affiliated member of the [Y] religion.',
#    'The [Y] religion has a person named [X] who is affiliated with it.',
#    'The [Y] religion has a person affiliated with it.',
#    'A person named [X] is affiliated with a religion.',
#    'The [Y] religion has a person named [X] affiliated with it.',
#    'The [Y] religion has a member called [X].',
#    '[X] is affiliated with another religion.',
#    'The [Y] religion has [X] associated with it.',
#    '[X] belongs to the [Y] religion.',
#    '[Y] religion is affiliated with [X].',
#    'The [Y] religion has an affiliated member called [X].',
#    '[X] is affiliated with the [Y] religion',
#    'The [Y] religion has a person named [X] associated with it.',
#    'The [Y] religion has a person associated with it.',
#    'The [Y] religion has an affiliated member named [X].',
#    '[X] is members of the [Y] religion.',
#    'The [Y] religion has a person associated with them.',
#    '[X] is connected with the [Y] religion.'],
#   'orig_template': '[X] is affiliated with the [Y] religion .'},
#  'P1412': {'generated_prompts': ['[X] used to speak in [Y].',
#    'In [Y], [X] used to communicate.',
#    '[X] used to communicate in [Y].',
#    '[Y] was used to communicate with [X].',
#    '[X] used to talk in [Y].',
#    'There was a time when [X] used to communicate in [Y].',
#    '[X] used to say something in [Y].',
#    '[X] communicated in [Y].',
#    '[X] used to communicate with [Y].',
#    'In the past, [X] used to communicate in [Y].',
#    'It was used to communicate in [Y].',
#    '[X] used to communicate in another language.',
#    'It used to be that [X] used to communicate in [Y].',
#    '[Y] was the language [X] used to communicate in.',
#    'The person used to communicate in [Y].',
#    'A person used to communicate in [Y].',
#    '[Y] is where [X] used to communicate.',
#    'There used to be a way for [X] to communicate in [Y].',
#    '[X] used to use [Y].',
#    '[X] used to use [Y] to communicate.',
#    'They used to communicate in [Y].',
#    '[X] used to communicate in [Y]',
#    'It used to be that [X] communicated in [Y].',
#    '[Y] used to be used to communicate with [X].',
#    '[X] was able to communicate in [Y].',
#    'There used to be a way for [X] to communicate with [Y].',
#    '[X] used to communicate using [Y].',
#    '[Y] was where [X] used to communicate.',
#    '[X] used to send and receive messages in [Y].',
#    'It was possible to communicate in [Y].',
#    '[X] used to communicate in a different language.',
#    'In [Y], [X] used to talk.',
#    'In the past, [X] communicated in [Y].',
#    'In [Y], [X] used to speak.',
#    '[Y] used to communicate with [X].',
#    'There used to be a way for [X] to communicate.',
#    '[X] used to communicate with [Y] in another language.',
#    '[X] used to speak in [Y]',
#    'There was a time when [X] used to communicate with [Y].',
#    '[X] and [Y] used to communicate.'],
#   'orig_template': '[X] used to communicate in [Y] .'},
#  'P159': {'generated_prompts': ['The headquarters of [X] is in [Y].',
#    'The headquarters of [X] is located in [Y].',
#    'The headquarters of [X] are in [Y].',
#    '[Y] is the headquarters of [X].',
#    "X's headquarters is in [Y].",
#    '[Y] is where the headquarter of [X] is located.',
#    'In [Y] is the headquarters of [X].',
#    'The head office of [X] is in [Y].',
#    '[Y] is where the headquarters of [X] is located.',
#    '[Y] is where the headquarters of [X] are located.',
#    'The office of [X] is in [Y].',
#    "It's the headquarters of [X] in [Y].",
#    '[Y] is the headquarter of [X].',
#    'In [Y], the headquarters of [X] is located.',
#    'The main office of [X] is in [Y].',
#    'There is a headquarters for [X] in [Y].',
#    'There is a headquarter of [X] in [Y].',
#    'The location of the headquarters of [X] is in [Y].',
#    'The base of [X] is in [Y].',
#    'The headquarter of [X] is in [Y].',
#    'The office of [X] is located in [Y].',
#    'The [X] headquarters is in [Y].',
#    "X's head office is in [Y].",
#    'The [Y] is where the headquarters of [X] are located.',
#    'There is a headquarter for [X] in [Y].',
#    'There is a headquarters of [X] in [Y].',
#    'In [Y] is the headquarter of [X].',
#    'The headquarters of [X] are located in [Y].',
#    '[Y] is the location of the headquarter of [X].',
#    'It is the headquarters of [X] in [Y].',
#    '[Y] is the location of the headquarters of [X].',
#    'The head office of [X] is located in [Y].',
#    'The headquarter of [X] is located in [Y].',
#    'The headquarters is in [Y].',
#    'The location of the headquarters of [X] is [Y].',
#    'There is a headquarter in [Y].',
#    '[Y] is where the headquarter of [X] is.',
#    'The headquarters of the organization is in [Y].',
#    'In [Y] the headquarters of [X] is located.',
#    'In [Y], the headquarters of [X] is.'],
#   'orig_template': 'The headquarter of [X] is in [Y] .'},
#  'P17': {'generated_prompts': ['[Y] is where [X] is located.',
#    '[Y] is the location of [X].',
#    'The location of [X] is in [Y].',
#    '[X] is in [Y].',
#    'There is a place called [X] located in [Y].',
#    'The location of [X] is [Y].',
#    'There is a place called [X] in [Y].',
#    '[Y] is located in [X].',
#    'You can find [X] in [Y].',
#    '[X] is located in [Y].',
#    'In [Y] is where [X] is located.',
#    '[Y] is the location for [X].',
#    '[Y] is the place where [X] is located.',
#    '[X] is in the same location as [Y].',
#    'In [Y], there is [X].',
#    'The place called [X] is located in [Y].',
#    '[Y] is where [X] is.',
#    '[X] is in the same area as [Y].',
#    '[X] is in the same place as [Y].',
#    'There is [X] in [Y].',
#    'There is [X] located in [Y].',
#    'It is located in [Y].',
#    'In [Y] is the location of [X].',
#    'There is a street called [X] located in [Y].',
#    '[Y] has [X] located in it.',
#    'There is a place named [X] located in [Y].',
#    'There is a street called [X] in [Y].',
#    'There is a person located in [Y].',
#    '[X] is in the same city as [Y].',
#    '[X] can be found in [Y].',
#    '[X] is in the city of [Y].',
#    'There is a street named [X] located in [Y].',
#    '[X] is located in the same location as [Y].',
#    '[X] is located in the same area as [Y].',
#    'There is a place named [X] in [Y].',
#    'A person is located in [Y].',
#    '[X] is located in the same place as [Y].',
#    '[Y] has [X] in it.',
#    "It's located in [Y].",
#    'There is a person in [Y].'],
#   'orig_template': '[X] is located in [Y] .'},
#  'P176': {'generated_prompts': ['[Y] is the producer of [X].',
#    '[Y] makes [X].',
#    '[Y] produces [X].',
#    '[X] is made by [Y].',
#    'The production of [X] is done by [Y].',
#    '[Y] produced [X].',
#    '[Y] is the creator of [X].',
#    '[Y] is the manufacturer of [X].',
#    '[Y] is responsible for producing [X].',
#    '[Y] is the maker of [X].',
#    '[X] is produced by another person.',
#    '[X] is manufactured by [Y].',
#    '[Y] is the production company for [X].',
#    '[Y] is the company that produces [X].',
#    'The producer of [X] is [Y].',
#    '[Y] is the company that produced [X].',
#    '[Y] is the company that makes [X].',
#    '[X] was produced by [Y].',
#    '[Y] is how [X] is produced.',
#    '[Y] is the person who produced [X].',
#    '[X] is created by [Y].',
#    "It's produced by [Y].",
#    '[Y] is the main producer of [X].',
#    'It is produced by [Y].',
#    'The production of [X] is by [Y].',
#    '[Y] creates [X].',
#    '[X] is produced by [Y].',
#    'The [X] is made by [Y].',
#    '[X] is produced by another.',
#    '[Y] is the producer.',
#    '[Y] is the person who produces [X].',
#    '[Y] is the producer of x.',
#    '[X] is a product of [Y].',
#    '[X] is a creation of [Y].',
#    'The [X] is produced by [Y].',
#    '[Y] is how [X] is made.',
#    '[Y] is the person who makes [X].',
#    '[X] is produced by other people.',
#    '[X] is made by another person.',
#    '[X] is produced by someone else.'],
#   'orig_template': '[X] is produced by [Y] .'},
#  'P178': {'generated_prompts': ['[Y] is the developer of [X].',
#    '[X] was developed by [Y].',
#    '[Y] is the creator of [X].',
#    '[Y] developed [X].',
#    '[Y] is the person who developed [X].',
#    '[Y] is the one who developed [X].',
#    '[Y] created [X].',
#    '[Y] was the one who developed [X].',
#    '[X] was created by [Y].',
#    '[Y] has developed [X].',
#    '[Y] is responsible for the development of [X].',
#    '[Y] is the author of [X].',
#    '[Y] is responsible for the creation of [X].',
#    'The [X] was developed by [Y].',
#    'The person who developed [X] is [Y].',
#    '[Y] is responsible for developing [X].',
#    '[Y] is the one who created [X].',
#    '[Y] develops [X].',
#    '[Y] is the person who created [X].',
#    '[X] is created by [Y].',
#    '[Y] was the developer of [X].',
#    'The [X] is developed by [Y].',
#    'The [X] is created by [Y].',
#    '[Y] is responsible for [X].',
#    'It was developed by [Y].',
#    '[Y] was responsible for the development of [X].',
#    '[X] is developed by another person.',
#    'The person who developed [X] was [Y].',
#    '[X] has been developed by [Y].',
#    '[X] was developed by another person.',
#    '[Y] is the one that developed [X].',
#    '[Y] is the originator of [X].',
#    '[Y] and [X] are the two people who developed [X].',
#    '[Y] is behind [X].',
#    '[Y] came up with the idea of [X].',
#    '[Y] came up with [X].',
#    '[Y] and [X] are related.',
#    '[Y] is how [X] is developed.',
#    '[Y] is the person who develops [X].',
#    '[Y] was responsible for developing [X].'],
#   'orig_template': '[X] is developed by [Y] .'},
#  'P19': {'generated_prompts': ['[Y] was where [X] was born.',
#    '[X] was born in [Y].',
#    '[Y] is where [X] was born.',
#    'The baby was born in [Y].',
#    'The child was born in [Y].',
#    "[Y] was the location of [X]'s birth.",
#    "[Y] is the location of [X]'s birth.",
#    '[X] was born in the year [Y].',
#    '[Y] was the location where [X] was born.',
#    '[X] was born in the same place as [Y].',
#    '[Y] was the place where [X] was born.',
#    '[Y] is the place where [X] was born.',
#    'The person was born in [Y].',
#    'There was a baby born in [Y].',
#    'It was [X] who was born in [Y].',
#    'In [Y], [X] was born.',
#    'He was born in [Y].',
#    'In [Y] is where [X] was born.',
#    'In [Y] was where [X] was born.',
#    '[Y] was the birth place of [X].',
#    'The birth place of [X] was [Y].',
#    'A person was born in [Y].',
#    'The born in [Y] was [X].',
#    'There is a baby born in [Y].',
#    '[X] was born on [Y].',
#    'The baby was born in the same place as [Y].',
#    '[X] was born in a different place.',
#    '[Y] was the place [X] was born in.',
#    '[X] was born in the same location as [Y].',
#    '[Y] was the place [X] was born.',
#    '[X] was born in [Y]',
#    'There was a baby in [Y].',
#    'I was born in [Y].',
#    '[X] was born into a family.',
#    '[X] was born in a different location.',
#    'There was a person born in [Y].',
#    '[X] was born in a different place than [Y].',
#    '[X] was born in the same year.',
#    '[X] was born in the same city as [Y].',
#    '[X] was born in [Y].'],
#   'orig_template': '[X] was born in [Y] .'},
#  'P190': {'generated_prompts': ['Twin cities are [X] and [Y].',
#    'Both [X] and [Y] are twin cities.',
#    'The twin cities are [X] and [Y].',
#    'There are two cities, [X] and [Y].',
#    'Both of the twin cities are [X] and [Y].',
#    '[X] and [Y] are both twin cities.',
#    'There are two twin cities, [X] and [Y].',
#    '[X] and [Y] are twin cities.',
#    'The cities of [X] and [Y] are twin.',
#    'Two cities are called [X] and [Y].',
#    'The cities are called [X] and [Y].',
#    'Twin Cities are [X] and [Y].',
#    'The two cities are called [X] and [Y].',
#    'Both [X] and [Y] are cities.',
#    'Both of the twin cities are called [X] and [Y].',
#    'Both [Y] and [X] are twin cities.',
#    'Two cities are [X] and [Y].',
#    'The cities of [X] and [Y] are identical.',
#    'There is a twin city called [X] and [Y].',
#    'The cities of [X] and [Y] are not the same.',
#    'The cities of [X] and [Y] are both twin cities.',
#    '[X] and [Y] are both cities.',
#    'Both cities are called [X] and [Y].',
#    '[X] and [Y] are the same city.',
#    'The cities of [X] and [Y] are related.',
#    '[X] and [Y] are not the same city.',
#    'They are both twin cities.',
#    'The cities of [X] and [Y] have the same name.',
#    'twin cities are [X] and [Y].',
#    '[Y] and [X] are twin cities.',
#    'They are twin cities.',
#    'The cities of [X] and [Y] are the same.',
#    'The cities of [X] and [Y] are similar.',
#    'The cities of [X] and [Y] are twin cities.',
#    'There are two twin cities.',
#    'Both [X] and [Y] are in the same area.',
#    'The cities of [X] and [Y] are very similar.',
#    '[X] and [Y] are not the same.',
#    'Both [X] and [Y] have twin cities.',
#    'The cities are twin.'],
#   'orig_template': '[X] and [Y] are twin cities .'},
#  'P20': {'generated_prompts': ['[X] died in [Y].',
#    '[X] passed away in [Y].',
#    '[Y] was where [X] died.',
#    'There was a death in [Y].',
#    'In [Y], [X] died.',
#    'The person died in [Y].',
#    '[Y] is where [X] died.',
#    'It was [X] who died in [Y].',
#    'There was a person who died in [Y].',
#    'He died in [Y].',
#    'The body of [X] was found in [Y].',
#    'The person died in the other place.',
#    "[Y] died of [X]'s death.",
#    'In [Y], [X] passed away.',
#    '[X] was dead in [Y].',
#    '[Y] was the place where [X] died.',
#    'It was [X] that died in [Y].',
#    'The death of [X] occurred in [Y].',
#    'The death of [X] was recorded in [Y].',
#    'The death of [X] happened in [Y].',
#    '[Y] was the place [X] died in.',
#    '[Y] was the location where [X] died.',
#    'The man died in [Y].',
#    '[Y] was where [X] passed away.',
#    '[X] expired in [Y].',
#    'There was a death in [Y] of [X].',
#    '[Y] was the place [X] died.',
#    '[X] died in [Y]',
#    '[X] passed away in [Y].',
#    'The person died in the other room.',
#    '[Y] had [X] die in it.',
#    '[X] was killed in [Y].',
#    'The person died in the other person.',
#    '[X] is dead in [Y].',
#    'A person died in another person.',
#    '[X] died while in [Y].',
#    'A person died in [Y].',
#    'The person died in the other direction.',
#    'The person died in the other body of water.',
#    'The person died in the same place as [X].'],
#   'orig_template': '[X] died in [Y] .'},
#  'P264': {'generated_prompts': ['[Y] is a music label.',
#    '[Y] is the music label that represents [X].',
#    '[Y] is a music label that represents [X].',
#    '[Y] is the music label for [X].',
#    'The music label [Y] is represented by [X].',
#    'Music label [Y] is represented by [X].',
#    '[Y] is the music label represented by [X].',
#    '[Y] is represented by [X].',
#    '[Y] is the music label representing [X].',
#    '[Y] is a music label for [X].',
#    '[Y] is the music label that is represented by [X].',
#    '[Y] is a music label that is represented by [X].',
#    '[Y] is the music label that [X] is represented by.',
#    'The label [Y] is represented by [X].',
#    'The music label [Y] represents [X].',
#    'A music label called [Y] is represented by [X].',
#    '[Y] is a music label representing [X].',
#    '[Y] is a music label represented by [X].',
#    '[Y] is the music label of [X].',
#    'A music label called [Y] represents [X].',
#    'Music label [Y] represents [X].',
#    'There is a music label called [Y].',
#    'The label [Y] represents [X].',
#    '[Y] is the label that represents [X].',
#    '[Y] is a label that represents [X].',
#    '[X] is represented by a music label.',
#    '[Y] is a music label with a representation of [X].',
#    '[Y] represents [X].',
#    "[Y] is [X]'s music label.",
#    'There is a music label called [X].',
#    '[Y] is the representation of [X].',
#    '[Y] is a music label that is associated with [X].',
#    'Music label [Y] is associated with [X].',
#    '[Y] is the music label that is representing [X].',
#    '[Y] is a music label',
#    'There is a music label called [Y] that represents [X].',
#    'A music label called [Y] is representing [X].',
#    'The music label [Y] has [X] represented.',
#    '[Y] is a music label and represents [X].',
#    '[Y] is a label for [X].'],
#   'orig_template': '[X] is represented by music label [Y] .'},
#  'P27': {'generated_prompts': ['[X] is a citizen.',
#    '[Y] is a citizen.',
#    '[Y] is a citizen of [X].',
#    '[Y] citizen is [X].',
#    '[Y] is a citizen of the United States.',
#    '[X] is a citizen of [Y].',
#    '[X] is a citizen of the United States.',
#    '[Y] is the citizen of [X].',
#    '[Y] is a citizen of the United States of America.',
#    'The person is called [Y] citizen.',
#    'There is a person named [X] who is a citizen.',
#    'There is a person called [X] who is a citizen.',
#    '[Y] is a citizen of the US.',
#    'The person is a citizen.',
#    '[Y] is a citizen of the world.',
#    '[X] is a citizen of the United States of America.',
#    "[Y] is [X]'s citizenship.",
#    '[Y] is a citizen and [X] is not.',
#    '[X] is a citizen of the world.',
#    '[X] is a citizen of the US.',
#    '[X] is a citizen of the country.',
#    'A person named [X] is a citizen of another country named [Y].',
#    '[X] is a person who is a citizen.',
#    '[Y] is a citizen of the country.',
#    '[Y] is an American citizen.',
#    'Is [X] a citizen?',
#    '[X] is a citizen of the nation.',
#    '[X] is a citizen of the state.',
#    '[Y] is a citizen of the nation.',
#    'There is a person named [X] who is a [Y] citizen.',
#    'The person is [Y] citizen.',
#    'There is a person called [X] who is a [Y] citizen.',
#    'There is a person named [X] who is a citizen of another country.',
#    'There is a person called [X] who is [Y] citizen.',
#    '[Y] citizens are [X] and [Y].',
#    'There is a person called [X] who is a citizen of [Y].',
#    'A person named [X] is a citizen of another country.',
#    'A person named [X] is a citizen of [Y].',
#    'There is a person called [X] who is a citizen of another country.',
#    'There is a person who is [Y] citizen.'],
#   'orig_template': '[X] is [Y] citizen .'},
#  'P276': {'generated_prompts': ['[Y] is where [X] is located.',
#    '[Y] is the location of [X].',
#    'The location of [X] is in [Y].',
#    '[X] is in [Y].',
#    'There is a place called [X] located in [Y].',
#    'The location of [X] is [Y].',
#    'There is a place called [X] in [Y].',
#    '[Y] is located in [X].',
#    'You can find [X] in [Y].',
#    '[X] is located in [Y].',
#    'In [Y] is where [X] is located.',
#    '[Y] is the location for [X].',
#    '[Y] is the place where [X] is located.',
#    '[X] is in the same location as [Y].',
#    'In [Y], there is [X].',
#    'The place called [X] is located in [Y].',
#    '[Y] is where [X] is.',
#    '[X] is in the same area as [Y].',
#    '[X] is in the same place as [Y].',
#    'There is [X] in [Y].',
#    'There is [X] located in [Y].',
#    'It is located in [Y].',
#    'In [Y] is the location of [X].',
#    'There is a street called [X] located in [Y].',
#    '[Y] has [X] located in it.',
#    'There is a place named [X] located in [Y].',
#    'There is a street called [X] in [Y].',
#    'There is a person located in [Y].',
#    '[X] is in the same city as [Y].',
#    '[X] can be found in [Y].',
#    '[X] is in the city of [Y].',
#    'There is a street named [X] located in [Y].',
#    '[X] is located in the same location as [Y].',
#    '[X] is located in the same area as [Y].',
#    'There is a place named [X] in [Y].',
#    'A person is located in [Y].',
#    '[X] is located in the same place as [Y].',
#    '[Y] has [X] in it.',
#    "It's located in [Y].",
#    'There is a person in [Y].'],
#   'orig_template': '[X] is located in [Y] .'},
#  'P279': {'generated_prompts': ['[X] is a subclass of [Y].',
#    '[Y] is a subclass of [X].',
#    'A subclass of [Y] is [X].',
#    'The subclass of [Y] is called [X].',
#    'The subclass of [Y] is [X].',
#    'There are two subclasses of [Y], [X] and [Y].',
#    'There is a subclass of [Y] called [X].',
#    'There are two subclasses of [Y]: [X] and [Y].',
#    "It's a subclass of [Y].",
#    '[X] is a subclass of [Y]',
#    'There is a subclass of [Y].',
#    'A subclass of [Y] is called [X].',
#    'It is a subclass of [Y].',
#    'There are two subclasses of [Y].',
#    "There's a subclass of [Y] called [X].",
#    'There are two subclass of [Y], [X] and [Y].',
#    '[X] is one of the subclasses of [Y].',
#    'The subclass of [Y] is known as [X].',
#    'There are two subclasses of [Y] - [X] and [Y].',
#    'There are two subclasses of [Y] called [X] and [Y].',
#    'A subclass of [Y] called [X] is also called a subclass of [Y].',
#    'The subclass [Y] is called [X].',
#    'The subclass of [Y] is referred to as [X].',
#    'The subclass of [X] is [Y].',
#    'The subclass [X] is called [Y].',
#    '[X] is part of [Y].',
#    'There is a subclass of [Y] that is called [X].',
#    '[X] and [Y] are subclasses of one another.',
#    '[X] is the subclass of [Y].',
#    "It's a subclass of [Y] called [X].",
#    'There are two subclasses of [Y]; [X] and [Y].',
#    "There's a subclass of [Y] that's called [X].",
#    '[X] is a subclass.',
#    'There are three subclasses of [Y]: [X], [Y] and [X].',
#    '[X] and [Y] are subclasses of [Y].',
#    'The subclass of [X] is called [Y].',
#    'There are two subclasses of [Y], called [X] and [Y].',
#    'There are two subclass of [Y].',
#    'This is a subclass of [Y].',
#    "It's a subclass of [Y] that's called [X]."],
#   'orig_template': '[X] is a subclass of [Y] .'},
#  'P30': {'generated_prompts': ['[Y] is where [X] is located.',
#    '[Y] is the location of [X].',
#    'The location of [X] is in [Y].',
#    '[X] is in [Y].',
#    'There is a place called [X] located in [Y].',
#    'The location of [X] is [Y].',
#    'There is a place called [X] in [Y].',
#    '[Y] is located in [X].',
#    'You can find [X] in [Y].',
#    '[X] is located in [Y].',
#    'In [Y] is where [X] is located.',
#    '[Y] is the location for [X].',
#    '[Y] is the place where [X] is located.',
#    '[X] is in the same location as [Y].',
#    'In [Y], there is [X].',
#    'The place called [X] is located in [Y].',
#    '[Y] is where [X] is.',
#    '[X] is in the same area as [Y].',
#    '[X] is in the same place as [Y].',
#    'There is [X] in [Y].',
#    'There is [X] located in [Y].',
#    'It is located in [Y].',
#    'In [Y] is the location of [X].',
#    'There is a street called [X] located in [Y].',
#    '[Y] has [X] located in it.',
#    'There is a place named [X] located in [Y].',
#    'There is a street called [X] in [Y].',
#    'There is a person located in [Y].',
#    '[X] is in the same city as [Y].',
#    '[X] can be found in [Y].',
#    '[X] is in the city of [Y].',
#    'There is a street named [X] located in [Y].',
#    '[X] is located in the same location as [Y].',
#    '[X] is located in the same area as [Y].',
#    'There is a place named [X] in [Y].',
#    'A person is located in [Y].',
#    '[X] is located in the same place as [Y].',
#    '[Y] has [X] in it.',
#    "It's located in [Y].",
#    'There is a person in [Y].'],
#   'orig_template': '[X] is located in [Y] .'},
#  'P31': {'generated_prompts': ['A [Y] is a [X].',
#    '[X] is a letter [Y].',
#    '[X] is a [Y].',
#    'There is a [Y] and a [X].',
#    "That's right, [X] is a [Y].",
#    'A [Y] is [X].',
#    '[X] and [Y] are the same thing.',
#    '[X] is the same as [Y].',
#    "It's a [Y], [X] is a [Y].",
#    "It's a [Y] if [X] is a [Y].",
#    '[Y] is a letter [X] is a letter [Y].',
#    'The letters [X] and [Y] are pronounced the same.',
#    'The letters [X] and [Y] are related.',
#    "It's a [Y] because [X] is a [Y].",
#    'There is a [Y] and [X].',
#    'The letters [X] and [Y] correspond to the same thing.',
#    'The letters [X] and [Y] are the same.',
#    '[Y] is a letter [X].',
#    'The letter [X] is a letter [Y].',
#    'A [Y] and [X] are the same thing.',
#    'There is an [X] and a [Y].',
#    "There's a [Y] and a [X].",
#    '[X] and [Y] are the same.',
#    'The letters [X] and [Y] are synonymous.',
#    '[X] is not a [Y].',
#    'There is a [Y] and an [X].',
#    '[X] is a digit.',
#    'The letter [X] is a [Y].',
#    'There is a [Y] and a [X] in this picture.',
#    'The letters [X] and [Y] are the same thing.',
#    'The letters [Y] and [X] are the same.',
#    'There is an [X] and an [Y].',
#    '[X] and [Y] are the same color.',
#    "It's a [Y] if [X] is it.",
#    '[X] is a symbol for [Y].',
#    "It's a [Y] with [X].",
#    'The letters [Y] and [X] are related.',
#    'A [Y] is an [X].',
#    'There is a [Y] in [X].',
#    'The letters [X] and [Y] are not the same.'],
#   'orig_template': '[X] is a [Y] .'},
#  'P36': {'generated_prompts': ['The capital of [X] is [Y].',
#    '[Y] is the capital of [X].',
#    'The capital is [Y].',
#    '[X] has a capital of [Y].',
#    'The capital of [Y] is [X].',
#    'The capital of [X] is [Y]',
#    '[X] is the capital of [Y].',
#    "X's capital is [Y].",
#    'The capital of [X] is called [Y].',
#    'The name of the capital of [X] is [Y].',
#    'The capital of [X] is the same as the capital of [Y].',
#    'There is a capital of [Y] in [X].',
#    'The capital of[X] is [Y].',
#    'There is a capital of [Y].',
#    'The capital city of [X] is [Y].',
#    'The capital is [Y] in [X].',
#    '[X] has a capital [Y].',
#    'The capital in [X] is [Y].',
#    'The capital of [X] is the letter [Y].',
#    'There is a capital in [X].',
#    'It is the capital of [X].',
#    'The name of the capital is [Y].',
#    'The capital of [X] is [Y].',
#    "It's the capital of [X].",
#    'The capital of [X] is also called [Y].',
#    'There is a capital [Y] in [X].',
#    "The capital of [X] is [Y], that's right.",
#    'A capital of [X] is [Y].',
#    'The capital of [X] is the [Y].',
#    'The capital of [X] is zero.',
#    '[X] is a capital letter [Y].',
#    '[Y] is the capital city of [X].',
#    'There is a capital of [X].',
#    'The capital of x is [Y].',
#    'The capital of the entity is [Y].',
#    'The capital of [X] was [Y].',
#    'The capital for [X] is [Y].',
#    '[Y] is the capital of [X]',
#    'The capital of [X] is a letter [Y].',
#    '[Y] is the capital ofX.'],
#   'orig_template': 'The capital of [X] is [Y] .'},
#  'P361': {'generated_prompts': ['[Y] is part of [X].',
#    '[Y] is a part of [X].',
#    '[Y] and [X] are part of the same thing.',
#    '[X] is part of [Y].',
#    '[X] is a part of [Y].',
#    'A part of [Y] is [X].',
#    'Part of [Y] is [X].',
#    "It's part of [Y].",
#    '[Y] and [X] are part of the same entity.',
#    '[X] and [Y] are part of the same thing.',
#    '[Y] and [X] are both part of the same thing.',
#    'The part of [Y] that is known as [X] is part of [Y].',
#    '[Y] and [X] are part of each other.',
#    '[Y] and [X] are part of the same place.',
#    'The part of [Y] that is known as [X] is also known as [Y].',
#    'It is part of [Y].',
#    'You can see that [X] is part of [Y].',
#    'There are two parts to [Y], [X] and [Y].',
#    '[Y] and [X] are both part of it.',
#    '[Y] and [X] are part of the same universe.',
#    "It's a part of [Y].",
#    '[Y] and [X] are part of the same body.',
#    '[X] and [Y] are both part of the same thing.',
#    '[Y] and [X] are part of the same family.',
#    '[Y] and [X] are part of the same structure.',
#    '[Y] and [X] are related.',
#    'The part of [Y] that is called [X] is called [Y].',
#    'The part of [Y] that is called [X] is part of [Y].',
#    '[Y] and [X] are part of the same group.',
#    '[Y] and [X] are parts of the same thing.',
#    '[X] and [Y] are part of the same entity.',
#    '[Y] and [X] are part of the same body of water.',
#    'The part of [Y] that is known as [X] is part of [Y] as well.',
#    '[Y] and [X] are part of the same system.',
#    '[Y] and [X] are both part of the same entity.',
#    '[Y] and [X] are part of it.',
#    '[Y] and [X] are both part of the same place.',
#    'The part of [Y] that is called [X] is also called [Y].',
#    'The part of [Y] called [X] is part of [X].',
#    '[Y] and [X] are part of one.'],
#   'orig_template': '[X] is part of [Y] .'},
#  'P364': {'generated_prompts': ['[Y] is the original language of [X].',
#    'The original language of [X] is [Y].',
#    'The original language is [Y].',
#    '[Y] was the original language of [X].',
#    'The original language of [X] was [Y].',
#    '[Y] is the original language for [X].',
#    "X's original language is [Y].",
#    'The language of [X] is [Y].',
#    'The original language for [X] is [Y].',
#    'The original language was [Y].',
#    'The first language of [X] is [Y].',
#    '[Y] is the language of [X].',
#    'The original language in [X] is [Y].',
#    'The original language of [X] is called [Y].',
#    '[Y] is the original language.',
#    'The language of [X] is called [Y].',
#    'The [Y] is the original language of [X].',
#    'The language of [X] was originally called [Y].',
#    '[Y] is the first language of [X].',
#    '[Y] is the original language of [X]',
#    'The original language for [X] was [Y].',
#    "It's the original language of [X].",
#    '[Y] is what the original language of [X] is.',
#    'The initial language of [X] is [Y].',
#    "X's original language was [Y].",
#    'It is the original language of [X].',
#    'The original language of [X] is [Y]',
#    'The original language is called [Y].',
#    'The original language of [X] was called [Y].',
#    '[Y] was the original language for [X].',
#    '[Y] is the original language ofX.',
#    '[Y] is the original Language of [X].',
#    '[Y] is the main language of [X].',
#    '[Y] is the original language of x.',
#    'The original language in [X] was [Y].',
#    'The [Y] language is the original one for [X].',
#    '[Y] is the original language in [X].',
#    '[X] is written in [Y].',
#    'There is a language called [Y] in [X].',
#    'The language of [X] was [Y].'],
#   'orig_template': 'The original language of [X] is [Y] .'},
#  'P37': {'generated_prompts': ['[Y] is the official language of [X].',
#    'The official language of [X] is [Y].',
#    'The language of [X] is [Y].',
#    'The official language is [Y].',
#    "X's official language is [Y].",
#    'The official language for [X] is [Y].',
#    'The official language in [X] is [Y].',
#    '[Y] is the official language.',
#    '[Y] is the official language for [X].',
#    '[Y] is the official language in [X].',
#    '[Y] is the language of [X].',
#    '[X] has an official language called [Y].',
#    'The [Y] is the official language of [X].',
#    '[Y] is the official Language of [X].',
#    'It is the official language of [X].',
#    '[Y] is the Official Language of [X].',
#    'The language of [X] is called [Y].',
#    '[X] is written in [Y].',
#    '[Y] is the official language of [X]',
#    'The official language of [X] is [Y]',
#    '[Y] is the official language ofX.',
# ...
#    'The letters [X] were written in [Y].',
#    'The words [X] were written in [Y].',
#    'The letter [X] was written in the middle of the letter [Y].',
#    'The word [X] is written in [Y].',
#    'The name [X] was written in [Y].',
#    'There was a letter [X] written in [Y].',
#    'The word [X] was written in the same language as [Y].',
#    'The letter [X] is written in [Y].',
#    'The letter [X] was written in the same language as the letter [Y].',
#    'The letter [X] was written in the letters [Y].',
#    'The [X] was written in [Y].',
#    'There was a word written in [Y].',
#    '[X] was written in [Y]',
#    'The letter [X] was written in the alphabet.',
#    '[Y] was the language of [X].',
#    'The word [X] was written in the same place as [Y].'],
#   'orig_template': '[X] was written in [Y] .'},
#  'P413': {'generated_prompts': ['[X] is in the [Y] position.',
#    '[X] plays in the [Y] position.',
#    '[X] is in [Y] position.',
#    '[X] plays in [Y] position.',
#    '[X] is playing in the [Y] position.',
#    '[X] plays in the [Y] position',
#    '[Y] is where [X] plays.',
#    'In [Y] position, [X] plays.',
#    '[X] plays in [Y].',
#    '[X] is in a [Y] position.',
#    'In the [Y] position, [X] plays.',
#    '[X] plays in a [Y] position.',
#    '[X] plays in [Y] position',
#    '[X] is playing in [Y] position.',
#    '[X] is a player in the [Y] position.',
#    '[Y] is the position [X] plays in.',
#    'The person plays in the [Y] position.',
#    'The person is in the [Y] position.',
#    'The [X] plays in the [Y] position.',
#    'The player is in the [Y] position.',
#    'The person is in [Y] position.',
#    '[X] is in the [Y] position',
#    'The person plays in [Y] position.',
#    '[Y] is the position where [X] plays.',
#    'The player is in [Y] position.',
#    '[X] plays in a certain position.',
#    'There is a person in the [Y] position.',
#    '[X] plays in the middle of the field.',
#    'There is a player in the [Y] position.',
#    '[X] is in [Y] position',
#    'The person is playing in [Y] position.',
#    '[X] plays the [Y] position.',
#    '[X] is in [Y].',
#    'In [Y] position is [X].',
#    '[X] is in the position of [Y].',
#    'The [X] plays in [Y] position.',
#    'The player plays in [Y] position.',
#    'In [Y] position, [X] is playing.',
#    '[Y] is the position [X] plays.',
#    'In the [Y] position is [X].'],
#   'orig_template': '[X] plays in [Y] position .'},
#  'P449': {'generated_prompts': ['The show was originally aired on [Y].',
#    '[X] was on [Y].',
#    '[X] was first aired on [Y].',
#    '[Y] was where [X] was originally aired.',
#    'The show was first aired on [Y].',
#    '[X] was broadcasted on [Y].',
#    'It was first aired on [Y].',
#    'On [Y], [X] was aired.',
#    '[X] was previously aired on [Y].',
#    'It was aired on [Y].',
#    'In the past, [X] was aired on [Y].',
#    'It was originally aired on [Y].',
#    '[X] used to be aired on [Y].',
#    '[X] was broadcast on [Y].',
#    '[Y] originally aired [X].',
#    'The show was aired on [Y].',
#    '[Y] was where [X] was first aired.',
#    '[Y] was the place where [X] was originally aired.',
#    '[X] used to be on [Y].',
#    '[Y] aired [X].',
#    '[X] was aired on [Y].',
#    'There was a show on [Y] called [X].',
#    'On [Y], there was a show called [X].',
#    '[X] was first broadcasted on [Y].',
#    'The show was on [Y].',
#    'The show was originally on [Y].',
#    '[X] was once aired on [Y].',
#    'The show was originally broadcasted on [Y].',
#    '[Y] was the place where [X] was first aired.',
#    '[X] aired on [Y].',
#    'On [Y], there was a program called [X].',
#    'There was a show called [X] on [Y].',
#    'It was on [Y].',
#    '[X] was originally aired on [Y].',
#    'There was a show on [Y] that was called [X].',
#    'There was a show called [X] that aired on [Y].',
#    'There was a show called [X] that was aired on [Y].',
#    'It was broadcasted on [Y].',
#    'In the past, [X] was broadcasted on [Y].',
#    '[X] originally aired on [Y].'],
#   'orig_template': '[X] was originally aired on [Y] .'},
#  'P463': {'generated_prompts': ['[Y] has [X] as a member.',
#    '[Y] has a member named [X].',
#    '[Y] has a member called [X].',
#    'A member of [Y] is [X].',
#    '[X] is not a member of [Y].',
#    '[Y] is a group of people with the same name.',
#    'The person is a member of [Y].',
#    'There is a person named [X] who is a member of [Y].',
#    '[Y] has a member known as [X].',
#    '[Y] has one member who is also a member of [X].',
#    'There is a person who is a member of [Y].',
#    '[Y] is a group with [X] as a member.',
#    '[Y] has one member named [X].',
#    '[Y] has x as a member.',
#    '[Y] has a member who is called [X].',
#    '[Y] has one member called [X].',
#    "Y's member is [X].",
#    'The member of [Y] is [X].',
#    '[Y] has a member who is [X].',
#    '[X] is a member of a group.',
#    'There is a person named [X] who is also a member of [Y].',
#    '[X] is a member of [Y].',
#    'A person is a member of [Y].',
#    '[X] is a member of a group called [Y].',
#    '[Y] has a member who is also a member of [X].',
#    '[Y] has [X] in it.',
#    '[Y] has a member who is also known as [X].',
#    'There is a member called [X].',
#    '[Y] has an individual named [X].',
#    'There is a person named [X] in this group.',
#    'There is a person named [X] who is in a group called [Y].',
#    'A person named [X] is a member of a group called [Y].',
#    'There is a person named [X] who is a part of [Y].',
#    'Someone is a member of [Y].',
#    '[Y] is a group of people.',
#    'There is a person named [X] who is a member of the group [Y].',
#    '[Y] is made up of [X] and others.',
#    'There is a member named [X].',
#    'There is a person named [X] who is a member of a group called [Y].',
#    'You are a member of [X].'],
#   'orig_template': '[X] is a member of [Y] .'},
#  'P47': {'generated_prompts': ['[X] shares a border with [Y].',
#    '[X] and [Y] share a border.',
#    'The border between [X] and [Y] is shared by 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884',
#    'The border is shared by [X] and [Y].',
#    '[X] and [Y] have the same border.',
#    '[X] has a border with [Y].',
#    'The border with [Y] is shared by [X] and [Y].',
#    '[X] and [Y] share the same border.',
#    'The border of [X] and [Y] is shared by 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884',
#    '[Y] shares a border with [X].',
#    'There is a border between [X] and [Y].',
#    'The [X] and [Y] border is shared by 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884 888-349-8884',
#    '[Y] and [X] share a border.',
#    '[X] and [Y] are in the same area.',
#    '[X] shares the same border with [Y].',
#    'Border with [Y] is shared by [X] and [Y].',
#    '[X] and [Y] have a border.',
#    'The border with [Y] is shared by [X] and [X].',
#    '[X] shares the border with [Y].',
#    '[X] and [Y] both share a border.',
#    'The border is [X] and [Y].',
#    '[X] and [Y] are near each other.',
#    'border with [Y] is shared by [X] and [Y].',
#    'The [X] and [Y] border.',
#    'The border between [X] and [Y] is [X].',
#    'The border between [X] and [Y] is shared by [X] and [Y].',
#    '[X] and [Y] are in the same place.',
#    'There is a border with [Y].',
#    '[X] and [Y] are close to each other.',
#    '[X] and [Y] both have a border.',
#    '[Y] and [X] share the same border.',
#    'Both [X] and [Y] share a border.',
#    '[X] and [Y] are both in the same area.',
#    '[X] shares border with [Y].',
#    '[X] and [Y] border each other.',
#    '[X] and [Y] are in the same border.',
#    '[X] and [Y] share the border.',
#    '[Y] shares border with [X].',
#    'The [X] and [Y] borders are similar.',
#    'Both [X] and [Y] have a border.'],
#   'orig_template': '[X] shares border with [Y] .'},
#  'P495': {'generated_prompts': ['[Y] was where [X] was created.',
#    '[Y] was the place where [X] was created.',
#    '[Y] is where [X] was created.',
#    'In [Y], [X] was created.',
#    '[X] was created in [Y].',
#    'The creation of [X] was done in [Y].',
#    'It was created in [Y].',
#    '[Y] was the location where [X] was created.',
#    '[Y] was where [X] was born.',
#    'The [X] was created in [Y].',
#    '[X] was created in the same place as [Y].',
#    '[X] was made in [Y].',
#    '[Y] was used to create [X].',
#    '[Y] is the place where [X] was created.',
#    '[Y] was where the [X] was created.',
#    '[X] was written in [Y].',
#    'The creation of [X] was in [Y].',
#    'There was a creation in [Y].',
#    '[Y] was the place [X] was created in.',
#    '[Y] was where [X] came from.',
#    '[X] was created by [Y].',
#    '[Y] was the place where [X] was born.',
#    '[Y] was where [X] was made.',
#    '[Y] had [X] created in it.',
#    '[Y] is where [X] was born.',
#    '[X] was born in [Y].',
#    'There was a creation called [X] in [Y].',
#    'A new thing was created in [Y].',
#    '[X] was created in a different place.',
#    '[Y] was the place where [X] was made.',
#    '[Y] was where the creation of [X] took place.',
#    'The [Y] was where [X] was created.',
#    'The [X] was created in the same place as [Y].',
#    '[Y] created [X].',
#    'The [X] was created in the same place as the [Y].',
#    '[X] was created in the same place.',
#    'The person created [X] in [Y].',
#    'The [X] was created in the [Y].',
#    '[Y] was the location of [X].',
#    'The thing was created in [Y].'],
#   'orig_template': '[X] was created in [Y] .'},
#  'P527': {'generated_prompts': ['[Y] is part of [X].',
#    '[X] is composed of [Y].',
#    '[X] is comprised of [Y].',
#    'There is [X] and [Y].',
#    '[X] is made up of [Y].',
#    'The [X] consists of [Y].',
#    '[Y] is a part of [X].',
#    '[Y] is included in [X].',
#    '[Y] consists of [X].',
#    '[Y] is comprised of [X].',
#    '[X] consists of [Y].',
#    'The [X] is composed of [Y].',
#    '[Y] is composed of [X].',
#    'There is [X] and [Y] in it.',
#    '[X] and [Y] are composed of one another.',
#    '[Y] is the part of [X].',
#    '[X] and [Y] are part of the same thing.',
#    'The [X] and [Y] are part of the same thing.',
#    'A part of [Y] is [X].',
#    'The [X] is made up of [Y].',
#    'It consists of [Y].',
#    '[X] has [Y] in it.',
#    '[X] and [Y] are part of it.',
#    'The [X] and [Y] are composed of one another.',
#    'There is [X] and [Y] in this picture.',
#    '[X] and [Y] are the same thing.',
#    'The [X] is comprised of [Y].',
#    'The [X] and [Y] are related.',
#    '[X] and [Y] are the same.',
#    'The [X] and [Y] are composed of the same thing.',
#    'It consists of [Y] and [X].',
#    'The [X] consists of the [Y].',
#    "There's [X] and [Y].",
#    'The [X] and [Y] are made of the same substance.',
#    '[X] is made of [Y].',
#    'The [X] and [Y] are made up of the same thing.',
#    '[Y] is in [X].',
#    "[Y] is [X]'s part.",
#    '[X] and [Y] are composed of the same thing.',
#    "[Y] is [X]'s component."],
#   'orig_template': '[X] consists of [Y] .'},
#  'P530': {'generated_prompts': ['[X] and [Y] have diplomatic relations.',
#    '[X] has diplomatic relations with [Y].',
#    '[X] and [Y] maintain diplomatic relations.',
#    'There are diplomatic relations between [X] and [Y].',
#    'There is diplomatic relations between [X] and [Y].',
#    '[X] maintains diplomatic relations with [Y].',
#    '[X] and [Y] still have diplomatic relations.',
#    '[X] and [Y] have diplomatic ties.',
#    '[Y] and [X] have diplomatic relations.',
#    'Diplomatic relations with [Y] are maintained by [X].',
#    'diplomatic relations with [Y] are maintained by [X].',
#    '[Y] has diplomatic relations with [X].',
#    '[X] and [Y] have diplomatic relationships.',
#    '[X] and [Y] still maintain diplomatic relations.',
#    'The [X] and [Y] have diplomatic relations.',
#    'The diplomatic relations between [X] and [Y] are maintained.',
#    '[X] is in diplomatic relations with [Y].',
#    '[X] has diplomatic ties with [Y].',
#    'diplomatic relations with [Y] are maintained by [X].',
#    '[X] maintains a diplomatic relationship with [Y].',
#    '[Y] and [X] maintain diplomatic relations.',
#    '[X] and [Y] both have diplomatic relations.',
#    '[X] is maintaining diplomatic relations with [Y].',
#    '[X] maintains diplomatic relations.',
#    'There are diplomatic relations with [Y].',
#    '[X] and [Y] are in diplomatic relations.',
#    '[X] maintains relations with [Y].',
#    'diplomatic relations with [Y].',
#    'There is diplomatic relations with [Y].',
#    '[X] has diplomatic relationships with [Y].',
#    '[X] and [Y] hold diplomatic relations.',
#    '[X] and [Y] have a diplomatic relationship.',
#    '[X] holds diplomatic relations with [Y].',
#    'diplomatic relations with [Y] are maintained by [X]',
#    'The two countries have diplomatic relations with [Y].',
#    'diplomatic relations with [Y]',
#    '[X] has diplomatic relations with [Y].',
#    '[X] and [Y] share diplomatic relations.',
#    '[X] and [Y] maintain diplomatic ties.',
#    '[X] and [Y] do not have diplomatic relations.'],
#   'orig_template': '[X] maintains diplomatic relations with [Y] .'},
#  'P740': {'generated_prompts': ['[Y] was where [X] was founded.',
#    '[Y] is where [X] was founded.',
#    '[X] was founded in [Y].',
#    'In [Y], [X] was founded.',
#    '[X] was started in [Y].',
#    '[Y] was the location of [X].',
#    'It was founded in [Y].',
#    '[X] was established in [Y].',
#    'In [Y] is where [X] was founded.',
#    '[X] was born in [Y].',
#    'The company was founded in [Y].',
#    '[Y] was where [X] was born.',
#    '[Y] was the location where [X] was founded.',
#    '[X] was created in [Y].',
#    '[Y] is the location of [X].',
#    '[Y] was the place where [X] was founded.',
#    '[X] was founded in the year [Y].',
#    'In [Y], there was a company called [X].',
#    'The founding of [X] was in [Y].',
#    '[X] was formed in [Y].',
#    'In [Y] was founded [X].',
#    '[X] was founded in the same place as [Y].',
#    '[X] was founded by [Y].',
#    '[Y] was the birthplace of [X].',
#    'A company called [X] was founded in [Y].',
#    '[Y] was where [X] was started.',
#    'The company [X] was founded in [Y].',
#    '[Y] is where [X] was started.',
#    '[X] was launched in [Y].',
#    '[Y] is where [X] was born.',
#    '[Y] was where [X] started.',
#    '[Y] was where [X] came from.',
#    '[X] was founded in a different place.',
#    '[Y] was where [X] began.',
#    'The company [X] was founded in.',
#    'The location of [X] was [Y].',
#    '[X] was founded in the same place.',
#    '[X] was begun in [Y].',
#    '[X] was founded in another place.',
#    'In [Y], there was a place called [X].'],
#   'orig_template': '[X] was founded in [Y] .'},
#  'P937': {'generated_prompts': ['[X] used to work in [Y].',
#    '[Y] was where [X] used to work.',
#    'In [Y], [X] used to work.',
#    'The person used to work in [Y].',
#    '[X] worked in [Y].',
#    '[Y] used to be where [X] used to work.',
#    '[X] used to work there.',
#    'There was a time when [X] used to work in [Y].',
#    'It was [X] who used to work in [Y].',
#    'He used to work in [Y].',
#    '[X] was once employed in [Y].',
#    '[X] used to work for [Y].',
#    'There was a time when [X] worked in [Y].',
#    'It used to be that [X] worked in [Y].',
#    "[Y] used to be [X]'s place of employment.",
#    '[X] was employed in [Y].',
#    'The man used to work in [Y].',
#    'They used to work in [Y].',
#    'In the past, [X] used to work in [Y].',
#    '[X] was used to work in [Y].',
#    'In the past, [X] worked in [Y].',
#    '[Y] is where [X] used to work.',
#    '[Y] used to be where [X] worked.',
#    '[X] once worked in [Y].',
#    '[X] used to work at [Y].',
#    'I used to work in [Y].',
#    'People used to work in [Y].',
#    '[X] used to work in [Y]',
#    '[X] used to work in the same place as [Y].',
#    'I used to work for [X] in [Y].',
#    '[X] used to work in another place.',
#    "[Y] used to be [X]'s place of work.",
#    'The guy used to work in [Y].',
#    '[X] used to work in the same building as [Y].',
#    'In [Y], [X] worked.',
#    '[X] used to work in a building.',
#    'The person used to work there.',
#    '[X] was a worker in [Y].',
#    '[X] used to work in another location.',
#    '[X] had a job in [Y].'],
#   'orig_template': '[X] used to work in [Y] .'}}

# %%
# loop over the final dict. Filter out bad templates.
# ex. Multiple [X] or [Y], missing [X] or [Y]
import re

def template_has_exactly_one_x_and_y(template_string):
  """returns true if a template has exactly one '[X]' and [Y]' in it (no more, no less)"""
  num_x = len( re.findall('\[X\]', template_string) )
  num_y = len( re.findall('\[Y\]', template_string) )
  return num_x == 1 and num_y == 1

final_dict = {}
for r, entry in new_templates_dict.items():
  subdict = {}
  subdict['orig_template'] = new_templates_dict[r]['orig_template']
  subdict['generated_prompts'] = [t for t in entry['generated_prompts'] if template_has_exactly_one_x_and_y(t)]
  final_dict[r] = subdict

final_dict['P101']
# Out:
# {'generated_prompts': ['The field of [Y] is being worked on by [X].',
#   'The field of [Y] is worked by [X].',
#   '[X] works in the field of [Y].',
#   'The field of [Y] is worked on by [X].',
#   'The field of [Y] is being worked in by [X].',
#   '[X] is in the field of [Y].',
#   'In the field of [Y], [X] works.',
#   'The field of [Y] is worked in by [X].',
#   '[X] is working in the field of [Y].',
#   'The field of [Y] is where [X] works.',
#   'The field of [Y] has [X] working in it.',
#   '[X] does work in the field of [Y].',
#   '[X] is involved in the field of [Y].',
#   '[X] works in the field of [Y]',
#   'The field of [Y] is occupied by [X].',
#   "[Y] is [X]'s field.",
#   '[Y] is the field that [X] works in.',
#   'The field of [Y] is what [X] works in.',
#   'There is a field of [Y] that [X] works in.',
#   'The field of [Y] is being worked upon by [X].',
#   '[Y] is a field that [X] works in.',
#   '[X] is employed in the field of [Y].',
#   '[Y] is the field [X] works in.',
#   '[X] works in [Y].',
#   "[Y] is [X]'s field of work.",
#   '[X] works in a field called [Y].',
#   'The field of [Y] is worked upon by [X].',
#   "The field of [Y] is [X]'s field.",
#   '[Y] is the field of [X].',
#   'The field of [Y] is done by [X].',
#   'The field of [Y] was worked by [X].',
#   '[X] works in the area of [Y].',
#   '[X] works in the [Y] field.'],
#  'orig_template': '[X] works in the field of [Y] .'}

# %%
# print number of valid prompt templates for each relation.
for k, val in final_dict.items():
  print(k, len(final_dict[k]['generated_prompts']))
# Out:
# P131 35
# P17 35
# P136 22
# P276 35
# P740 34
# P140 33
# P37 31
# P413 28
# P159 35
# P19 25
# P279 23
# P27 12
# P20 27
# P103 31
# P361 29
# P30 35
# P47 33
# P190 36
# P1303 29
# P527 39
# P495 34
# P1001 23
# P1376 28
# P264 35
# P530 34
# P39 34
# P101 33
# P138 36
# P463 27
# P937 28
# P176 31
# P106 27
# P364 30
# P127 29
# P449 29
# P407 33
# P36 28
# P31 35
# P178 36
# P108 27
# P1412 32

# %%
# finally, export the cleaned prompts dict to json
final_fileName = 'paraphrased_prompt_templates.json'
with open("/content/drive/MyDrive/"+final_fileName, "w") as outfile2:
      json.dump(final_dict, outfile2)
      print("Exported json.")
# Out:
# Exported json.
